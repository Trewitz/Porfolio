# %% [markdown]
# # Predicting stock indices using Long Short Term Memory networks
#
# ## Overview
#
# * [Technical indicators](#Technical-indicators)
# * [Data setup](#Downloading-cleaning)
# * [Basic EDA](#EDA)
# * [Model building](#Model-building)
# * [Hyperparameter optimization](#Hyperparameter-tuning)
# * [Training and vizualizing prediction error](#Training-vizu)
# * [Backtesting](#Backtesting)
# * [Conclusion](#Conclusion)
#
#
# ### Short introduction
#
# The prediction of stock markets have always been a discussed topic and there is different way to trade the stock market. This notebook tries to develop a trading algorithm for index which can be traded through futures or CFD's. The approach for this notebook is to use a LSTM RNN. RNN's is a special structured nerual network layout and is developed with predicting sequences of data in mind, which you can say the stock prices is a very good example of.
#
# The data that is used  is the main indices from Europe but this setup can easily be expanded to include any other index or even be used on individual stock prices. Daily OHLC data from Yahoo Finance can easily be downloaded, and furthermore the data is enriched with currency exchange rates indiced that might have some predictable power on the indices such as EURUSD, EURGBP etc. One of the hypothesis is that a volatility index would also have a predictive power however unfortunately the historical data from VDAX is not available from Yahoo Finance as a proxy we use the VIX, which might give a measure of the overall volatilty in the global economy.

# %% [markdown]
# ## Packages imports

# %%
## Package imports
import os
import datetime

## The usual suspects
import pandas as pd
import numpy as np

## Visualization tools
# %matplotlib inline  
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.metrics import confusion_matrix, roc_curve, auc, roc_auc_score

## Packages for downloading financial data
import yfinance as yf

## Neural network tools
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras import Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint

## Bayesian optimization tools
from bayes_opt import BayesianOptimization
from functools import partial

## Set seed for reproduceability
np.random.seed(1)
plt.style.use('dark_background')

# %%
## Function to time code.
def tic():
    import time
    global startTime_for_tictoc
    startTime_for_tictoc = time.time()

def toc():
    import time
    if 'startTime_for_tictoc' in globals():
        print("Elapsed time is " + str(time.time() - startTime_for_tictoc) + " seconds.")
    else:
        print("Toc: start time not set")

# %% [markdown]
# ## Technical indicators as features <a class="anchor" id="Technical-indicators">
# Technical indicator is widely used by many practioneers (technical analysis) such as Simple Moving Averages (SMA), Bollinger Bands etc. to predict whether the stock is likely to move up or down. We enrich the data with some of the most common techinal indicators SMA, Bollinger Bands, RSI, MACD and Fast Fourier Transforms. It can easily incorporate more indicators if needed

# %%
## Setup functions for adding features and format data
def macd(data, a, b):
    return data['Close'].ewm(span=a).mean() - data['Close'].ewm(span=b).mean()

def bollinger_bands(data, flag):
    sma = data['Close'].rolling(window=20).mean()
    smv = data['Close'].rolling(window=20).std()
    if flag == 'Upper':
        return sma + 2 * smv
    elif flag == 'Lower':
        return sma - 2 * smv
    else:
        raise ValueError('Wrong input.')
        
def rsi(data):
    df_ret = data['Close'].pct_change()
    g = df_ret * (df_ret > 0)
    l = df_ret * (df_ret < 0)
    avg_g = g.rolling(window=14).mean()
    avg_l = l.rolling(window=14).mean()
    rs = abs(avg_g.divide(avg_l))
    return 100 * rs / (1 + rs)

def fft_indicator(data, k):
    sp = np.fft.fft(data['Close'])
    return abs(np.fft.ifft(sp[:k], len(data)))

def addFeatures(data):
    sma_days = [10,50,100,200]

    for days in sma_days:
        data.loc[:, 'sma' + str(days)] = data['Close'].rolling(window=days).mean()
        data.loc[:, 'ema' + str(days)] = data['Close'].ewm(span=days).mean()

    data.loc[:, 'MACD'] = macd(data, 12, 26)
    data.loc[:, 'BB_Upper'] = bollinger_bands(data, 'Upper')
    data.loc[:, 'BB_Lower'] = bollinger_bands(data, 'Lower')
    data.loc[:, 'RSI'] = rsi(data)
    
    data.dropna(inplace=True)
    
    data.loc[:, 'fft3'] = fft_indicator(data,3)
    data.loc[:, 'fft6'] = fft_indicator(data,6)
    data.loc[:, 'fft9'] = fft_indicator(data,9)
    
    return data

def nnFormat(data, window=4):
    nrows = data.shape[0]
    ncols = data.shape[1]

    features = np.zeros(shape=(0, window, ncols - 2))
    label1 = np.zeros(shape=(0,1))
    label2 = np.zeros(shape=(0,1))
    
    for i in range(window,nrows-1):
        features = np.append(features, data.iloc[i-window:i,0:(ncols-2)].to_numpy().reshape(1, window, ncols - 2), axis=0)
        label1 = np.append(label1, data.iloc[i, ncols-2].reshape(1,1), axis=0)
        label2 = np.append(label2, data.iloc[i, ncols-1].reshape(1,1), axis=0)
    
    
    return features, label1, label2

# %% [markdown]
# ## Downloading and cleaning data <a class="anchor" id="Downloading-cleaning">

# %%
startDate = '2007-01-02'

## Download currency data + VIX
curr_vix_list = ['EURUSD=X', 'EURGBP=X', 'EURSEK=X', 'EURJPY=X', 'EURCNY=X', '^VIX']
curr_vix_data = yf.download(curr_vix_list, start=startDate)
curr_vix_data = curr_vix_data['Close']
curr_vix_data = curr_vix_data.rename(columns={"EURUSD=X": "EURUSD", 
                                      "EURGBP=X": "EURGBP", 
                                      "EURSEK=X": "EURSEK", 
                                      "EURJPY=X": "EURJPY",
                                      "EURCNY=X": "EURCNY"})

indices = ['^STOXX50E', '^N100', '^BFX', '^GDAXI', '^FTSE', '^FCHI']

sequence_length = 20
features = np.zeros(shape=(0, sequence_length, 25))
label1 = np.zeros(shape=(0,1))
label2 = np.zeros(shape=(0,1))

for ind in indices:
    print(ind)
    data = yf.download(ind, start=startDate)
    data = pd.concat([data, curr_vix_data], axis=1)
    data.fillna(method='ffill', inplace=True)
    data.drop(['Volume', 'Adj Close'], axis=1, inplace=True)
    data = addFeatures(data)
    
    data.loc[:, 'Gradient'] = ((data.loc[:, 'Close'] - data.loc[:, 'Close'].shift())/data.loc[:, 'Close'].shift() + 1).shift(-1)
    data.dropna(inplace=True)
    buySell = data.loc[:, 'Gradient'] > 1 
    
    ## Normalizing data
    norm_data = (data - data.min())/(data.max() - data.min())
    norm_data.loc[:, 'BuySell'] = buySell.astype(int)
    
    tempFeatures, tempLabel1, tempLabel2 = nnFormat(norm_data,sequence_length)
    
    features = np.append(features, tempFeatures, axis=0)
    label1 = np.append(label1, tempLabel1, axis=0)
    label2 = np.append(label2, tempLabel2, axis=0)
# Out:
# [*********************100%***********************]  6 of 6 completed
# ^STOXX50E
# [*********************100%***********************]  1 of 1 completed
# ^N100
# [*********************100%***********************]  1 of 1 completed
# ^BFX
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# [*********************100%***********************]  1 of 1 completed
# ^FTSE
# [*********************100%***********************]  1 of 1 completed
# ^FCHI
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Basic EDA <a class="anchor" id="EDA">
#
# Just to get a quick feel of how the data behaves we take a look at the german index DAX and the features that is added to the data.

# %%
data = yf.download('^GDAXI', start=startDate, progress=False)
data = pd.concat([data, curr_vix_data], axis=1)
data.fillna(method='ffill', inplace=True)
data.drop(['Volume', 'Adj Close'], axis=1, inplace=True)
data = addFeatures(data)

# %%
## Plot closing prices
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(18,10))
fig.suptitle('DAX', fontsize=20)
ax.set_ylabel('Close', fontsize=16)
ax.set_xlabel('Date', fontsize=16)
ax = data['Close'].plot(color=(31/255,119/255,180/255))
ax = data['sma50'].plot()
ax = data['sma200'].plot()
ax.legend();

# %% [markdown]
# Data since 2007-01-01 is included to have the lastest financial crisis in the data the reason for not taking all data available is that you could argue that algorithmic trading have gone up significantly over the last couple of years and have changed the way stocks and indiced are being traded and this is what the model to try to capture not have stocks were traded 20 years ago. So to have a reasonable ammount of data the first data entry is from 2007.
#
# In this data set there is the latest financial crises in 2008 and ofcause the recent dip in the stock markets because of the corona virus.
#
# Next lets take a look at the correlation between the features in the model.

# %%
## Correlation plot
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(18,10))
sn.heatmap(data.corr(), cmap='Blues', ax=ax, vmin=-1, vmax=1)
ax.tick_params(axis='x', rotation=-45)
ax.invert_yaxis()

# %% [markdown]
# The correlation is set between -1 to 1 where 1 corresponds with perferct positive correlation i.e. if the close price goes up the feature also goes up in the similar fashion and -1 is then given by the opposite. As we would expect some of the simple features that is based on the close price have a close correlation with the close price. Remember the task is basically to predict the next close price.

# %% [markdown]
# ## Train-Val-Test-Split
#
# The split is done randomly from the dataset. So that every 20 length sequence with corresponding label is a independent observation. This however can be a problem when we look at the generalization error as the the model have been exposed to data points around the test set that is shared for training examples and test example because the each data point consist of a sequence of 20 days. You could instead base the validation set and training set on the dates such that newer data is the validation and test set respectively. The last section in this notebook a backtesting with an index that the model never has seen before is performed to see how well the model performs in terms of return.

# %%
## Splitting data into training, validation and test sets
index = np.random.permutation(features.shape[0])

training_idx, validation_idx, test_idx = index[:int(features.shape[0]*0.8)], index[int(features.shape[0]*0.8):int(features.shape[0]*0.95)], index[int(features.shape[0]*0.95):]
train_features, validation_features, test_features = features[training_idx,:], features[validation_idx,:], features[test_idx,:]
train_label1, validation_label1, test_label1 = label1[training_idx,:], label1[validation_idx,:], label1[test_idx,:]
train_label2, validation_label2, test_label2 = label2[training_idx,:], label2[validation_idx,:], label2[test_idx,:]

# %% [markdown]
# ## Model building <a class="anchor" id="Model-building">
#
# Different layouts for the model have been tryed ending with a dual output LSTM model. So the main idea of this model is to predict whether the index goes up or down the following period the intuitive way is to see this only as a classification problem but some problems may arise from this. If model is solely based on classfication it is not penalized how far the model is from the actual change. This can result in that when the model makes a wrong prediction the loss can much higher than gain when the prediction is on point and the model is only evaluated on how if the price goes up or down. Which is why the model is built such that it also tries to predict the change in the index. Giving us a model that both minimizes the binary crossentropy on the classification problem and a mean squared error on predictition of the change in the index.
#
# One thing to be aware of when using LSTM is that the gradient can explode which is why clipping the gradient is used. Here we use keras implementation with the clipnorm. As a regularizer we use the simple dropout technique and treat learning rate, clipnorm, batch size and dropout rate as hyperparameters to be optimized. For the dense layer just before the sigmoid layer the scaled exponential linear unit is used.

# %%
## Model building
def get_model(input_shape, 
              lstm_layer_1_nodes,
              lstm_layer_2_nodes,
              dense_layer_nodes,
              dropout_rate):
    
    input_layer = Input(shape=input_shape, name='Input_Layer')
    
    lstm_layer_1 = LSTM(lstm_layer_1_nodes, 
                        dropout = dropout_rate, 
                        return_sequences=True, 
                        name='First_LSTM_Layer')(input_layer)
    
    lstm_layer_2 = LSTM(lstm_layer_2_nodes, 
                        dropout = dropout_rate,
                        name='Second_LSTM_Layer')(lstm_layer_1)
    
    dense_layer_1 = Dense(dense_layer_nodes, 
                          activation='selu', 
                          name='First_Dense_Layer')(lstm_layer_2)
    
    dropout_layer_1 = Dropout(dropout_rate, 
                              name='First_Dropout_Layer')(dense_layer_1)
    
    output_layer_1 = Dense(1,
                          activation=None,
                          name='Gradient_Prediction')(lstm_layer_2)
    
    output_layer_2 = Dense(1,
                          activation='sigmoid',
                          name='BuySell_Prediction')(dropout_layer_1)

    lstm_model = Model(input_layer, [output_layer_1, output_layer_2])
    
    
    return lstm_model

def fit_model(input_shape,
              dropout_rate,
              lr,
              batch_size,
              clipnorm):
    
    lstm_layer_1_nodes = 75
    lstm_layer_2_nodes = 75
    dense_layer_nodes = 50

    lstm_model = get_model(input_shape, 
                           int(lstm_layer_1_nodes),
                           int(lstm_layer_2_nodes),
                           int(dense_layer_nodes),
                           dropout_rate)
    
    opt = Adam(lr=lr, clipnorm=clipnorm)
    
    loss = {
    'Gradient_Prediction': 'mean_squared_error',
    'BuySell_Prediction': 'binary_crossentropy'
    }

    metrics = {
        'BuySell_Prediction': 'accuracy'
    }

    lstm_model.compile(optimizer=opt,
                      loss=loss,
                      metrics=metrics)
    
    mcp = ModelCheckpoint(checkpoint_path, 
                          monitor='val_BuySell_Prediction_accuracy', 
                          mode='max', 
                          save_best_only=True,
                          save_weights_only=True)
    
    lstm_model.fit(train_features, [train_label1, train_label2],
                   epochs=50,
                   batch_size=int(batch_size),
                   validation_data = [validation_features, {'Gradient_Prediction': validation_label1,
                                                                                'BuySell_Prediction': validation_label2}],
                   callbacks=[mcp],
                   verbose=0)
    
    lstm_model.load_weights('baysianOpt/cp.ckpt')
    
    score = lstm_model.evaluate(validation_features, [validation_label1, validation_label2], verbose=0)

    return score[3]

# %% [markdown]
# ## Hyperparameter tuning <a class="anchor" id="Hyperparameter-tuning">
#
# As stated above the parameters for tuning is the learning rate, clipnorm, batch size and dropout rate. For this an implementation of baysian optimization is used. The baysian optimization makes the tuning of the hyperparameter into a new optimization problem meaning that hopefully the model does not have to be trained to many times before a set of optimal or near optimal hyperparameters can be chosen for the fully trainined model. Because of the computational power it takes to fully train the neural network the baysian optimization is done on 50 epochs with early stopping. Evaluating the performance of the model on the accuracy. Need to check wether the accuracy is better if the combined losses is used instead.

# %%
## Baysian optimization

checkpoint_path = 'baysianOpt/cp.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)

fit_model_partial = partial(fit_model, (features.shape[1], features.shape[2]))

tic()
pbounds = {'dropout_rate': (0.1, 0.35), 
           'lr': (1e-5, 1e-2),
           'batch_size':(128,256),
           'clipnorm':(0.5,1.5)}

optimizer = BayesianOptimization(
    f=fit_model_partial,
    pbounds=pbounds,
    verbose=2,
    random_state=1
)

optimizer.maximize(init_points=5, n_iter=20)

baysianOptimum = optimizer.max

toc()
# Out:
# |   iter    |  target   | batch_... | clipnorm  | dropou... |    lr     |
# -------------------------------------------------------------------------
# |  1        |  0.5304   |  181.4    |  1.22     |  0.1      |  0.00303  |
# |  2        |  0.5324   |  146.8    |  0.5923   |  0.1466   |  0.003462 |
# |  3        |  0.5256   |  178.8    |  1.039    |  0.2048   |  0.006855 |
# |  4        |  0.5307   |  154.2    |  1.378    |  0.1068   |  0.006708 |
# |  5        |  0.5342   |  181.4    |  1.059    |  0.1351   |  0.001989 |
# |  6        |  0.5396   |  256.0    |  0.5      |  0.1287   |  0.003365 |
# |  7        |  0.5245   |  225.1    |  0.5316   |  0.32     |  0.006916 |
# |  8        |  0.5208   |  128.1    |  1.459    |  0.2792   |  0.009179 |
# |  9        |  0.5314   |  202.1    |  0.52     |  0.3359   |  0.002766 |
# |  10       |  0.5314   |  243.6    |  1.453    |  0.1371   |  0.003628 |
# |  11       |  0.5362   |  256.0    |  1.496    |  0.3452   |  0.002052 |
# |  12       |  0.5297   |  194.4    |  1.442    |  0.1097   |  0.002078 |
# |  13       |  0.5307   |  255.8    |  0.5339   |  0.1102   |  0.003305 |
# |  14       |  0.5297   |  235.4    |  0.516    |  0.2786   |  0.002517 |
# |  15       |  0.5249   |  187.1    |  0.5002   |  0.3391   |  0.006868 |
# |  16       |  0.5204   |  213.8    |  1.493    |  0.3006   |  0.00499  |
# |  17       |  0.5245   |  136.8    |  1.492    |  0.2582   |  0.008875 |
# |  18       |  0.5314   |  164.3    |  0.5178   |  0.1972   |  0.006304 |
# |  19       |  0.5304   |  131.9    |  0.5088   |  0.1388   |  0.003762 |
# |  20       |  0.5345   |  255.9    |  1.489    |  0.1128   |  0.006359 |
# |  21       |  0.5321   |  250.8    |  0.51     |  0.3234   |  0.002977 |
# |  22       |  0.5294   |  202.8    |  0.5182   |  0.1152   |  0.008889 |
# |  23       |  0.5328   |  256.0    |  0.5122   |  0.3177   |  0.008193 |
# |  24       |  0.5383   |  255.8    |  1.453    |  0.1224   |  0.003192 |
# |  25       |  0.5359   |  255.8    |  1.451    |  0.1276   |  0.005037 |
# =========================================================================
# Elapsed time is 11616.50178694725 seconds.

# %%
accuracy_list = [i['target'] for i in optimizer.res]
batch_size_list = [int(i['params']['batch_size']) for i in optimizer.res]
clipnorm_list = [i['params']['clipnorm'] for i in optimizer.res]
dropout_rate_list = [i['params']['dropout_rate'] for i in optimizer.res]
lr_list = [i['params']['lr'] for i in optimizer.res]


fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(15,8))
fig.suptitle('Baysian Optimization (n-iter=25)', fontsize=16)

ax[0][0].scatter(batch_size_list, accuracy_list)
ax[0][0].set_title("Batch size")

ax[0][1].scatter(clipnorm_list, accuracy_list)
ax[0][1].set_title('Clipnorm')

ax[1][0].scatter(dropout_rate_list, accuracy_list)
ax[1][0].set_title('Dropout rate')

ax[1][1].scatter(lr_list, accuracy_list)
ax[1][1].set_title('Learning rate');

# %% [markdown]
# It is unclear wether the baysian optimization actually learned something, and we maybe should have used random search instead, which can be even more computationally heavy (for the setup i am currently running it would be infeasible). For now we set the hyperparameters from the baysian optimization and try to do the full training.

# %%
input_shape = (features.shape[1], features.shape[2])
lstm_layer_1_nodes = 75
lstm_layer_2_nodes = 75
dense_layer_nodes = 50

useBayesian = True 

if useBayesian:
    dropout_rate = baysianOptimum['params']['dropout_rate']
    batch_size = int(baysianOptimum['params']['batch_size'])
    clipnorm = baysianOptimum['params']['clipnorm']
    lr = baysianOptimum['params']['lr']
else:
    dropout_rate = 0.1
    batch_size = 229
    clipnorm = 1.5
    lr = 0.003088

lstm_model = get_model(input_shape, 
              lstm_layer_1_nodes,
              lstm_layer_2_nodes,
              dense_layer_nodes,
              dropout_rate)

opt = Adam(lr=lr, clipnorm=clipnorm)

loss = {
    'Gradient_Prediction': 'mean_squared_error',
    'BuySell_Prediction': 'binary_crossentropy'
}

metrics = {
    'BuySell_Prediction': 'accuracy'
}
lstm_model.compile(optimizer=opt,
                  loss=loss,
                  metrics=metrics)

lstm_model.summary()
# Out:
# Model: "model_25"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input_Layer (InputLayer)        [(None, 20, 25)]     0
# __________________________________________________________________________________________________
# First_LSTM_Layer (LSTM)         (None, 20, 75)       30300       Input_Layer[0][0]
# __________________________________________________________________________________________________
# Second_LSTM_Layer (LSTM)        (None, 75)           45300       First_LSTM_Layer[0][0]
# __________________________________________________________________________________________________
# First_Dense_Layer (Dense)       (None, 50)           3800        Second_LSTM_Layer[0][0]
# __________________________________________________________________________________________________
# First_Dropout_Layer (Dropout)   (None, 50)           0           First_Dense_Layer[0][0]
# __________________________________________________________________________________________________
# Gradient_Prediction (Dense)     (None, 1)            76          Second_LSTM_Layer[0][0]
# __________________________________________________________________________________________________
# BuySell_Prediction (Dense)      (None, 1)            51          First_Dropout_Layer[0][0]
# ==================================================================================================
# Total params: 79,527
# Trainable params: 79,527
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Model training  <a class="anchor" id="Training-vizu">
#
# For model training we use the parameters from the baysian optimization and it seems that the model converges after aprox. 1000 epochs. During training we make checkpoints based on the accuracy meaning that we save the weights corresponding with the best performing model based on accuracy on the validation set (early stopping). This is done especially because the loss function is quite volatile but also to make sure that going forward we are sure to use the best model that were achieved through training.

# %%
## Setup Checkpoints for early stopping
checkpoint_path = 'twoOutputCheckpoints/cp.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)

mcp = ModelCheckpoint(checkpoint_path, 
                          monitor='val_BuySell_Prediction_accuracy', 
                          mode='max', 
                          save_best_only=True,
                          save_weights_only=True)

tic()
model_history = lstm_model.fit(train_features, 
                               {'Gradient_Prediction': train_label1,
                                'BuySell_Prediction': train_label2},
                               epochs=1000,
                               validation_data = [validation_features, {'Gradient_Prediction': validation_label1,
                                                                        'BuySell_Prediction': validation_label2}],
                               batch_size=batch_size,
                               callbacks=[mcp],
                               verbose=2
                              )
toc()
# Out:
# Train on 15536 samples, validate on 2913 samples
# Epoch 1/1000
# 15536/15536 - 11s - loss: 0.7259 - Gradient_Prediction_loss: 0.0300 - BuySell_Prediction_loss: 0.6957 - BuySell_Prediction_accuracy: 0.5015 - val_loss: 0.6980 - val_Gradient_Prediction_loss: 0.0049 - val_BuySell_Prediction_loss: 0.6931 - val_BuySell_Prediction_accuracy: 0.5070
# Epoch 2/1000
# 15536/15536 - 8s - loss: 0.7004 - Gradient_Prediction_loss: 0.0047 - BuySell_Prediction_loss: 0.6957 - BuySell_Prediction_accuracy: 0.5009 - val_loss: 0.6976 - val_Gradient_Prediction_loss: 0.0046 - val_BuySell_Prediction_loss: 0.6930 - val_BuySell_Prediction_accuracy: 0.5088
# Epoch 3/1000
# 15536/15536 - 8s - loss: 0.6985 - Gradient_Prediction_loss: 0.0045 - BuySell_Prediction_loss: 0.6940 - BuySell_Prediction_accuracy: 0.5076 - val_loss: 0.6987 - val_Gradient_Prediction_loss: 0.0045 - val_BuySell_Prediction_loss: 0.6941 - val_BuySell_Prediction_accuracy: 0.4940
# Epoch 4/1000
# 15536/15536 - 8s - loss: 0.6974 - Gradient_Prediction_loss: 0.0044 - BuySell_Prediction_loss: 0.6931 - BuySell_Prediction_accuracy: 0.5115 - val_loss: 0.6982 - val_Gradient_Prediction_loss: 0.0045 - val_BuySell_Prediction_loss: 0.6938 - val_BuySell_Prediction_accuracy: 0.5057
# Epoch 5/1000
# 15536/15536 - 8s - loss: 0.6976 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6934 - BuySell_Prediction_accuracy: 0.5050 - val_loss: 0.6973 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6930 - val_BuySell_Prediction_accuracy: 0.5074
# Epoch 6/1000
# 15536/15536 - 8s - loss: 0.6975 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6933 - BuySell_Prediction_accuracy: 0.5098 - val_loss: 0.6973 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6930 - val_BuySell_Prediction_accuracy: 0.5088
# Epoch 7/1000
# 15536/15536 - 8s - loss: 0.6980 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6937 - BuySell_Prediction_accuracy: 0.5034 - val_loss: 0.6983 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6939 - val_BuySell_Prediction_accuracy: 0.4943
# Epoch 8/1000
# 15536/15536 - 8s - loss: 0.6970 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6928 - BuySell_Prediction_accuracy: 0.5127 - val_loss: 0.6981 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6937 - val_BuySell_Prediction_accuracy: 0.5009
# Epoch 9/1000
# 15536/15536 - 8s - loss: 0.6970 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6927 - BuySell_Prediction_accuracy: 0.5156 - val_loss: 0.6996 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6952 - val_BuySell_Prediction_accuracy: 0.4950
# Epoch 10/1000
# 15536/15536 - 8s - loss: 0.6972 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6930 - BuySell_Prediction_accuracy: 0.5112 - val_loss: 0.6972 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6929 - val_BuySell_Prediction_accuracy: 0.5115
# Epoch 11/1000
# 15536/15536 - 8s - loss: 0.6965 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6923 - BuySell_Prediction_accuracy: 0.5207 - val_loss: 0.6972 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6930 - val_BuySell_Prediction_accuracy: 0.5115
# Epoch 12/1000
# 15536/15536 - 8s - loss: 0.6968 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6926 - BuySell_Prediction_accuracy: 0.5141 - val_loss: 0.6974 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6932 - val_BuySell_Prediction_accuracy: 0.5125
# Epoch 13/1000
# 15536/15536 - 8s - loss: 0.6962 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6920 - BuySell_Prediction_accuracy: 0.5174 - val_loss: 0.6972 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6929 - val_BuySell_Prediction_accuracy: 0.5191
# Epoch 14/1000
# 15536/15536 - 8s - loss: 0.6972 - Gradient_Prediction_loss: 0.0044 - BuySell_Prediction_loss: 0.6928 - BuySell_Prediction_accuracy: 0.5144 - val_loss: 0.6969 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6927 - val_BuySell_Prediction_accuracy: 0.5129
# Epoch 15/1000
# 15536/15536 - 7s - loss: 0.6963 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6922 - BuySell_Prediction_accuracy: 0.5181 - val_loss: 0.6973 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6931 - val_BuySell_Prediction_accuracy: 0.5122
# Epoch 16/1000
# 15536/15536 - 7s - loss: 0.6966 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6925 - BuySell_Prediction_accuracy: 0.5167 - val_loss: 0.6981 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6940 - val_BuySell_Prediction_accuracy: 0.5070
# Epoch 17/1000
# 15536/15536 - 7s - loss: 0.6963 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6920 - BuySell_Prediction_accuracy: 0.5197 - val_loss: 0.6981 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6937 - val_BuySell_Prediction_accuracy: 0.5108
# Epoch 18/1000
# 15536/15536 - 7s - loss: 0.6971 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6929 - BuySell_Prediction_accuracy: 0.5118 - val_loss: 0.6973 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6930 - val_BuySell_Prediction_accuracy: 0.5153
# Epoch 19/1000
# 15536/15536 - 8s - loss: 0.6962 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6921 - BuySell_Prediction_accuracy: 0.5179 - val_loss: 0.6967 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6924 - val_BuySell_Prediction_accuracy: 0.5194
# Epoch 20/1000
# 15536/15536 - 7s - loss: 0.6959 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6917 - BuySell_Prediction_accuracy: 0.5193 - val_loss: 0.6970 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6926 - val_BuySell_Prediction_accuracy: 0.5153
# Epoch 21/1000
# 15536/15536 - 7s - loss: 0.6961 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6920 - BuySell_Prediction_accuracy: 0.5195 - val_loss: 0.6972 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6928 - val_BuySell_Prediction_accuracy: 0.5132
# Epoch 22/1000
# 15536/15536 - 8s - loss: 0.6960 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6919 - BuySell_Prediction_accuracy: 0.5186 - val_loss: 0.6971 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6930 - val_BuySell_Prediction_accuracy: 0.5098
# Epoch 23/1000
# 15536/15536 - 8s - loss: 0.6956 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6914 - BuySell_Prediction_accuracy: 0.5176 - val_loss: 0.6983 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6941 - val_BuySell_Prediction_accuracy: 0.5098
# Epoch 24/1000
# 15536/15536 - 7s - loss: 0.6963 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6921 - BuySell_Prediction_accuracy: 0.5193 - val_loss: 0.6975 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6933 - val_BuySell_Prediction_accuracy: 0.5077
# Epoch 25/1000
# 15536/15536 - 8s - loss: 0.6958 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6917 - BuySell_Prediction_accuracy: 0.5187 - val_loss: 0.6967 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6924 - val_BuySell_Prediction_accuracy: 0.5256
# Epoch 26/1000
# 15536/15536 - 7s - loss: 0.6955 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6913 - BuySell_Prediction_accuracy: 0.5300 - val_loss: 0.6967 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6925 - val_BuySell_Prediction_accuracy: 0.5132
# Epoch 27/1000
# 15536/15536 - 7s - loss: 0.6962 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6921 - BuySell_Prediction_accuracy: 0.5185 - val_loss: 0.6961 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6918 - val_BuySell_Prediction_accuracy: 0.5242
# Epoch 28/1000
# 15536/15536 - 8s - loss: 0.6950 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6909 - BuySell_Prediction_accuracy: 0.5255 - val_loss: 0.6977 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6933 - val_BuySell_Prediction_accuracy: 0.5142
# Epoch 29/1000
# 15536/15536 - 7s - loss: 0.6964 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6921 - BuySell_Prediction_accuracy: 0.5144 - val_loss: 0.6970 - val_Gradient_Prediction_loss: 0.0045 - val_BuySell_Prediction_loss: 0.6925 - val_BuySell_Prediction_accuracy: 0.5118
# Epoch 30/1000
# 15536/15536 - 8s - loss: 0.6960 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6918 - BuySell_Prediction_accuracy: 0.5151 - val_loss: 0.6966 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6923 - val_BuySell_Prediction_accuracy: 0.5194
# Epoch 31/1000
# 15536/15536 - 7s - loss: 0.6955 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6914 - BuySell_Prediction_accuracy: 0.5212 - val_loss: 0.6972 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6927 - val_BuySell_Prediction_accuracy: 0.5177
# Epoch 32/1000
# 15536/15536 - 7s - loss: 0.6954 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6913 - BuySell_Prediction_accuracy: 0.5203 - val_loss: 0.6966 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6922 - val_BuySell_Prediction_accuracy: 0.5194
# Epoch 33/1000
# 15536/15536 - 8s - loss: 0.6949 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6908 - BuySell_Prediction_accuracy: 0.5291 - val_loss: 0.6968 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6926 - val_BuySell_Prediction_accuracy: 0.5160
# Epoch 34/1000
# 15536/15536 - 7s - loss: 0.6953 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6912 - BuySell_Prediction_accuracy: 0.5227 - val_loss: 0.6961 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6918 - val_BuySell_Prediction_accuracy: 0.5177
# Epoch 35/1000
# 15536/15536 - 7s - loss: 0.6944 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6904 - BuySell_Prediction_accuracy: 0.5314 - val_loss: 0.6960 - val_Gradient_Prediction_loss: 0.0045 - val_BuySell_Prediction_loss: 0.6917 - val_BuySell_Prediction_accuracy: 0.5342
# Epoch 36/1000
# 15536/15536 - 7s - loss: 0.6951 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6909 - BuySell_Prediction_accuracy: 0.5248 - val_loss: 0.6961 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6917 - val_BuySell_Prediction_accuracy: 0.5266
# Epoch 37/1000
# 15536/15536 - 7s - loss: 0.6948 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6907 - BuySell_Prediction_accuracy: 0.5259 - val_loss: 0.6966 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6923 - val_BuySell_Prediction_accuracy: 0.5239
# Epoch 38/1000
# 15536/15536 - 7s - loss: 0.6952 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6910 - BuySell_Prediction_accuracy: 0.5261 - val_loss: 0.6966 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6923 - val_BuySell_Prediction_accuracy: 0.5215
# Epoch 39/1000
# 15536/15536 - 7s - loss: 0.6956 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6914 - BuySell_Prediction_accuracy: 0.5244 - val_loss: 0.6967 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6923 - val_BuySell_Prediction_accuracy: 0.5091
# Epoch 40/1000
# 15536/15536 - 7s - loss: 0.6951 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6910 - BuySell_Prediction_accuracy: 0.5253 - val_loss: 0.6959 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6915 - val_BuySell_Prediction_accuracy: 0.5273
# Epoch 41/1000
# 15536/15536 - 7s - loss: 0.6943 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6902 - BuySell_Prediction_accuracy: 0.5270 - val_loss: 0.6954 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6911 - val_BuySell_Prediction_accuracy: 0.5280
# Epoch 42/1000
# 15536/15536 - 7s - loss: 0.6949 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6908 - BuySell_Prediction_accuracy: 0.5256 - val_loss: 0.6955 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6912 - val_BuySell_Prediction_accuracy: 0.5263
# Epoch 43/1000
# 15536/15536 - 7s - loss: 0.6947 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6907 - BuySell_Prediction_accuracy: 0.5285 - val_loss: 0.6962 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6918 - val_BuySell_Prediction_accuracy: 0.5187
# Epoch 44/1000
# 15536/15536 - 7s - loss: 0.6951 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6909 - BuySell_Prediction_accuracy: 0.5257 - val_loss: 0.6956 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6913 - val_BuySell_Prediction_accuracy: 0.5201
# Epoch 45/1000
# 15536/15536 - 7s - loss: 0.6943 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6901 - BuySell_Prediction_accuracy: 0.5276 - val_loss: 0.6952 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6909 - val_BuySell_Prediction_accuracy: 0.5166
# Epoch 46/1000
# 15536/15536 - 7s - loss: 0.6938 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6897 - BuySell_Prediction_accuracy: 0.5274 - val_loss: 0.6957 - val_Gradient_Prediction_loss: 0.0045 - val_BuySell_Prediction_loss: 0.6912 - val_BuySell_Prediction_accuracy: 0.5221
# Epoch 47/1000
# 15536/15536 - 7s - loss: 0.6942 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6901 - BuySell_Prediction_accuracy: 0.5278 - val_loss: 0.6957 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6914 - val_BuySell_Prediction_accuracy: 0.5324
# Epoch 48/1000
# 15536/15536 - 7s - loss: 0.6940 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6900 - BuySell_Prediction_accuracy: 0.5302 - val_loss: 0.6965 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6922 - val_BuySell_Prediction_accuracy: 0.5129
# Epoch 49/1000
# 15536/15536 - 7s - loss: 0.6936 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6896 - BuySell_Prediction_accuracy: 0.5302 - val_loss: 0.6962 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6918 - val_BuySell_Prediction_accuracy: 0.5249
# Epoch 50/1000
# 15536/15536 - 7s - loss: 0.6937 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6896 - BuySell_Prediction_accuracy: 0.5314 - val_loss: 0.6957 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6912 - val_BuySell_Prediction_accuracy: 0.5194
# Epoch 51/1000
# 15536/15536 - 7s - loss: 0.6940 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6900 - BuySell_Prediction_accuracy: 0.5293 - val_loss: 0.6958 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6915 - val_BuySell_Prediction_accuracy: 0.5252
# Epoch 52/1000
# 15536/15536 - 7s - loss: 0.6946 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6906 - BuySell_Prediction_accuracy: 0.5242 - val_loss: 0.6955 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6912 - val_BuySell_Prediction_accuracy: 0.5156
# Epoch 53/1000
# 15536/15536 - 7s - loss: 0.6935 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6894 - BuySell_Prediction_accuracy: 0.5328 - val_loss: 0.6952 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6909 - val_BuySell_Prediction_accuracy: 0.5245
# Epoch 54/1000
# 15536/15536 - 7s - loss: 0.6936 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6895 - BuySell_Prediction_accuracy: 0.5340 - val_loss: 0.6950 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6907 - val_BuySell_Prediction_accuracy: 0.5187
# Epoch 55/1000
# 15536/15536 - 7s - loss: 0.6927 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6887 - BuySell_Prediction_accuracy: 0.5348 - val_loss: 0.6953 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6910 - val_BuySell_Prediction_accuracy: 0.5269
# Epoch 56/1000
# 15536/15536 - 7s - loss: 0.6937 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6896 - BuySell_Prediction_accuracy: 0.5233 - val_loss: 0.6953 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6910 - val_BuySell_Prediction_accuracy: 0.5208
# Epoch 57/1000
# 15536/15536 - 7s - loss: 0.6932 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6890 - BuySell_Prediction_accuracy: 0.5284 - val_loss: 0.6957 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6914 - val_BuySell_Prediction_accuracy: 0.5180
# Epoch 58/1000
# 15536/15536 - 7s - loss: 0.6934 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6893 - BuySell_Prediction_accuracy: 0.5294 - val_loss: 0.6960 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6917 - val_BuySell_Prediction_accuracy: 0.5170
# Epoch 59/1000
# 15536/15536 - 7s - loss: 0.6932 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6891 - BuySell_Prediction_accuracy: 0.5342 - val_loss: 0.6956 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6913 - val_BuySell_Prediction_accuracy: 0.5211
# Epoch 60/1000
# 15536/15536 - 7s - loss: 0.6929 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6889 - BuySell_Prediction_accuracy: 0.5339 - val_loss: 0.6952 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6909 - val_BuySell_Prediction_accuracy: 0.5259
# Epoch 61/1000
# 15536/15536 - 7s - loss: 0.6937 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6897 - BuySell_Prediction_accuracy: 0.5360 - val_loss: 0.6963 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6920 - val_BuySell_Prediction_accuracy: 0.5194
# Epoch 62/1000
# 15536/15536 - 7s - loss: 0.6939 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6899 - BuySell_Prediction_accuracy: 0.5313 - val_loss: 0.6955 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6912 - val_BuySell_Prediction_accuracy: 0.5132
# Epoch 63/1000
# 15536/15536 - 7s - loss: 0.6931 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6891 - BuySell_Prediction_accuracy: 0.5320 - val_loss: 0.6960 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6917 - val_BuySell_Prediction_accuracy: 0.5139
# Epoch 64/1000
# 15536/15536 - 7s - loss: 0.6932 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6891 - BuySell_Prediction_accuracy: 0.5333 - val_loss: 0.6963 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6921 - val_BuySell_Prediction_accuracy: 0.5163
# Epoch 65/1000
# 15536/15536 - 7s - loss: 0.6922 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6881 - BuySell_Prediction_accuracy: 0.5310 - val_loss: 0.6961 - val_Gradient_Prediction_loss: 0.0047 - val_BuySell_Prediction_loss: 0.6913 - val_BuySell_Prediction_accuracy: 0.5294
# Epoch 66/1000
# 15536/15536 - 7s - loss: 0.6929 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6888 - BuySell_Prediction_accuracy: 0.5315 - val_loss: 0.6953 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6908 - val_BuySell_Prediction_accuracy: 0.5269
# Epoch 67/1000
# 15536/15536 - 7s - loss: 0.6921 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6880 - BuySell_Prediction_accuracy: 0.5295 - val_loss: 0.6975 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6931 - val_BuySell_Prediction_accuracy: 0.5129
# Epoch 68/1000
# 15536/15536 - 7s - loss: 0.6925 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6884 - BuySell_Prediction_accuracy: 0.5367 - val_loss: 0.6948 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6906 - val_BuySell_Prediction_accuracy: 0.5249
# Epoch 69/1000
# 15536/15536 - 7s - loss: 0.6925 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6885 - BuySell_Prediction_accuracy: 0.5344 - val_loss: 0.6948 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6904 - val_BuySell_Prediction_accuracy: 0.5187
# Epoch 70/1000
# 15536/15536 - 8s - loss: 0.6924 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6883 - BuySell_Prediction_accuracy: 0.5340 - val_loss: 0.6942 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6897 - val_BuySell_Prediction_accuracy: 0.5283
# Epoch 71/1000
# 15536/15536 - 7s - loss: 0.6914 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6873 - BuySell_Prediction_accuracy: 0.5321 - val_loss: 0.6962 - val_Gradient_Prediction_loss: 0.0045 - val_BuySell_Prediction_loss: 0.6919 - val_BuySell_Prediction_accuracy: 0.5215
# Epoch 72/1000
# 15536/15536 - 7s - loss: 0.6936 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6895 - BuySell_Prediction_accuracy: 0.5277 - val_loss: 0.6944 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6901 - val_BuySell_Prediction_accuracy: 0.5194
# Epoch 73/1000
# 15536/15536 - 7s - loss: 0.6923 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6883 - BuySell_Prediction_accuracy: 0.5350 - val_loss: 0.6952 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6909 - val_BuySell_Prediction_accuracy: 0.5163
# Epoch 74/1000
# 15536/15536 - 7s - loss: 0.6926 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6886 - BuySell_Prediction_accuracy: 0.5328 - val_loss: 0.6962 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6919 - val_BuySell_Prediction_accuracy: 0.5170
# Epoch 75/1000
# 15536/15536 - 7s - loss: 0.6923 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6883 - BuySell_Prediction_accuracy: 0.5333 - val_loss: 0.6943 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6899 - val_BuySell_Prediction_accuracy: 0.5232
# Epoch 76/1000
# 15536/15536 - 7s - loss: 0.6924 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6883 - BuySell_Prediction_accuracy: 0.5317 - val_loss: 0.6947 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6905 - val_BuySell_Prediction_accuracy: 0.5173
# Epoch 77/1000
# 15536/15536 - 7s - loss: 0.6916 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6875 - BuySell_Prediction_accuracy: 0.5296 - val_loss: 0.6957 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6914 - val_BuySell_Prediction_accuracy: 0.5215
# Epoch 78/1000
# 15536/15536 - 7s - loss: 0.6914 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6874 - BuySell_Prediction_accuracy: 0.5320 - val_loss: 0.6951 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6910 - val_BuySell_Prediction_accuracy: 0.5232
# Epoch 79/1000
# 15536/15536 - 7s - loss: 0.6922 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6881 - BuySell_Prediction_accuracy: 0.5299 - val_loss: 0.6944 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6900 - val_BuySell_Prediction_accuracy: 0.5304
# Epoch 80/1000
# 15536/15536 - 7s - loss: 0.6924 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6883 - BuySell_Prediction_accuracy: 0.5297 - val_loss: 0.6942 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6899 - val_BuySell_Prediction_accuracy: 0.5060
# Epoch 81/1000
# 15536/15536 - 7s - loss: 0.6911 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6871 - BuySell_Prediction_accuracy: 0.5375 - val_loss: 0.6937 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6894 - val_BuySell_Prediction_accuracy: 0.5259
# Epoch 82/1000
# 15536/15536 - 7s - loss: 0.6923 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6883 - BuySell_Prediction_accuracy: 0.5362 - val_loss: 0.6962 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6920 - val_BuySell_Prediction_accuracy: 0.5191
# Epoch 83/1000
# 15536/15536 - 7s - loss: 0.6917 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6876 - BuySell_Prediction_accuracy: 0.5331 - val_loss: 0.6937 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6895 - val_BuySell_Prediction_accuracy: 0.5197
# Epoch 84/1000
# 15536/15536 - 7s - loss: 0.6917 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6877 - BuySell_Prediction_accuracy: 0.5405 - val_loss: 0.6949 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6906 - val_BuySell_Prediction_accuracy: 0.5177
# Epoch 85/1000
# 15536/15536 - 7s - loss: 0.6923 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6882 - BuySell_Prediction_accuracy: 0.5303 - val_loss: 0.6950 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6907 - val_BuySell_Prediction_accuracy: 0.5249
# Epoch 86/1000
# 15536/15536 - 7s - loss: 0.6916 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6875 - BuySell_Prediction_accuracy: 0.5355 - val_loss: 0.6945 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6902 - val_BuySell_Prediction_accuracy: 0.5156
# Epoch 87/1000
# 15536/15536 - 7s - loss: 0.6924 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6883 - BuySell_Prediction_accuracy: 0.5290 - val_loss: 0.6948 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6904 - val_BuySell_Prediction_accuracy: 0.5290
# Epoch 88/1000
# 15536/15536 - 7s - loss: 0.6919 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6879 - BuySell_Prediction_accuracy: 0.5360 - val_loss: 0.6935 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6893 - val_BuySell_Prediction_accuracy: 0.5146
# Epoch 89/1000
# 15536/15536 - 7s - loss: 0.6904 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6864 - BuySell_Prediction_accuracy: 0.5329 - val_loss: 0.6935 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6892 - val_BuySell_Prediction_accuracy: 0.5197
# Epoch 90/1000
# 15536/15536 - 7s - loss: 0.6909 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6868 - BuySell_Prediction_accuracy: 0.5366 - val_loss: 0.6934 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6889 - val_BuySell_Prediction_accuracy: 0.5342
# Epoch 91/1000
# 15536/15536 - 7s - loss: 0.6906 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6865 - BuySell_Prediction_accuracy: 0.5373 - val_loss: 0.6927 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6886 - val_BuySell_Prediction_accuracy: 0.5266
# Epoch 92/1000
# 15536/15536 - 7s - loss: 0.6912 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6871 - BuySell_Prediction_accuracy: 0.5383 - val_loss: 0.6938 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6893 - val_BuySell_Prediction_accuracy: 0.5187
# Epoch 93/1000
# 15536/15536 - 7s - loss: 0.6904 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6863 - BuySell_Prediction_accuracy: 0.5405 - val_loss: 0.6964 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6921 - val_BuySell_Prediction_accuracy: 0.5197
# Epoch 94/1000
# 15536/15536 - 7s - loss: 0.6906 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6865 - BuySell_Prediction_accuracy: 0.5304 - val_loss: 0.6935 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6893 - val_BuySell_Prediction_accuracy: 0.5156
# Epoch 95/1000
# 15536/15536 - 7s - loss: 0.6901 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6861 - BuySell_Prediction_accuracy: 0.5391 - val_loss: 0.6921 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6880 - val_BuySell_Prediction_accuracy: 0.5263
# Epoch 96/1000
# 15536/15536 - 7s - loss: 0.6902 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6862 - BuySell_Prediction_accuracy: 0.5415 - val_loss: 0.6938 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6894 - val_BuySell_Prediction_accuracy: 0.5290
# Epoch 97/1000
# 15536/15536 - 7s - loss: 0.6903 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6864 - BuySell_Prediction_accuracy: 0.5354 - val_loss: 0.6946 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6903 - val_BuySell_Prediction_accuracy: 0.5156
# Epoch 98/1000
# 15536/15536 - 7s - loss: 0.6890 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6850 - BuySell_Prediction_accuracy: 0.5416 - val_loss: 0.6928 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6882 - val_BuySell_Prediction_accuracy: 0.5187
# Epoch 99/1000
# 15536/15536 - 7s - loss: 0.6903 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6861 - BuySell_Prediction_accuracy: 0.5411 - val_loss: 0.6933 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6890 - val_BuySell_Prediction_accuracy: 0.5249
# Epoch 100/1000
# 15536/15536 - 7s - loss: 0.6896 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6857 - BuySell_Prediction_accuracy: 0.5398 - val_loss: 0.6922 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6880 - val_BuySell_Prediction_accuracy: 0.5239
# Epoch 101/1000
# 15536/15536 - 7s - loss: 0.6878 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6838 - BuySell_Prediction_accuracy: 0.5372 - val_loss: 0.6930 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6888 - val_BuySell_Prediction_accuracy: 0.5215
# Epoch 102/1000
# 15536/15536 - 7s - loss: 0.6897 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6857 - BuySell_Prediction_accuracy: 0.5366 - val_loss: 0.6925 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6882 - val_BuySell_Prediction_accuracy: 0.5225
# Epoch 103/1000
# 15536/15536 - 7s - loss: 0.6882 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6842 - BuySell_Prediction_accuracy: 0.5474 - val_loss: 0.6929 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6884 - val_BuySell_Prediction_accuracy: 0.5173
# Epoch 104/1000
# 15536/15536 - 7s - loss: 0.6879 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6839 - BuySell_Prediction_accuracy: 0.5436 - val_loss: 0.6933 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6892 - val_BuySell_Prediction_accuracy: 0.5201
# Epoch 105/1000
# 15536/15536 - 7s - loss: 0.6888 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6847 - BuySell_Prediction_accuracy: 0.5410 - val_loss: 0.6922 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6880 - val_BuySell_Prediction_accuracy: 0.5283
# Epoch 106/1000
# 15536/15536 - 7s - loss: 0.6897 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6857 - BuySell_Prediction_accuracy: 0.5446 - val_loss: 0.6906 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6863 - val_BuySell_Prediction_accuracy: 0.5328
# Epoch 107/1000
# 15536/15536 - 7s - loss: 0.6886 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6844 - BuySell_Prediction_accuracy: 0.5428 - val_loss: 0.6915 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6873 - val_BuySell_Prediction_accuracy: 0.5287
# Epoch 108/1000
# 15536/15536 - 7s - loss: 0.6883 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6845 - BuySell_Prediction_accuracy: 0.5404 - val_loss: 0.6917 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6874 - val_BuySell_Prediction_accuracy: 0.5269
# Epoch 109/1000
# 15536/15536 - 7s - loss: 0.6874 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6833 - BuySell_Prediction_accuracy: 0.5422 - val_loss: 0.6965 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6921 - val_BuySell_Prediction_accuracy: 0.5149
# Epoch 110/1000
# 15536/15536 - 7s - loss: 0.6878 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6838 - BuySell_Prediction_accuracy: 0.5465 - val_loss: 0.6906 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6863 - val_BuySell_Prediction_accuracy: 0.5276
# Epoch 111/1000
# 15536/15536 - 7s - loss: 0.6872 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6832 - BuySell_Prediction_accuracy: 0.5434 - val_loss: 0.6916 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6878 - val_BuySell_Prediction_accuracy: 0.5372
# Epoch 112/1000
# 15536/15536 - 7s - loss: 0.6881 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6841 - BuySell_Prediction_accuracy: 0.5429 - val_loss: 0.6924 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6880 - val_BuySell_Prediction_accuracy: 0.5307
# Epoch 113/1000
# 15536/15536 - 7s - loss: 0.6864 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6824 - BuySell_Prediction_accuracy: 0.5407 - val_loss: 0.6924 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6880 - val_BuySell_Prediction_accuracy: 0.5328
# Epoch 114/1000
# 15536/15536 - 7s - loss: 0.6865 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6825 - BuySell_Prediction_accuracy: 0.5458 - val_loss: 0.6897 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6854 - val_BuySell_Prediction_accuracy: 0.5438
# Epoch 115/1000
# 15536/15536 - 7s - loss: 0.6863 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6824 - BuySell_Prediction_accuracy: 0.5425 - val_loss: 0.6919 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6871 - val_BuySell_Prediction_accuracy: 0.5239
# Epoch 116/1000
# 15536/15536 - 7s - loss: 0.6849 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6809 - BuySell_Prediction_accuracy: 0.5504 - val_loss: 0.6910 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6871 - val_BuySell_Prediction_accuracy: 0.5352
# Epoch 117/1000
# 15536/15536 - 7s - loss: 0.6846 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6806 - BuySell_Prediction_accuracy: 0.5512 - val_loss: 0.6965 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6921 - val_BuySell_Prediction_accuracy: 0.5136
# Epoch 118/1000
# 15536/15536 - 7s - loss: 0.6881 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6841 - BuySell_Prediction_accuracy: 0.5391 - val_loss: 0.6895 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6845 - val_BuySell_Prediction_accuracy: 0.5403
# Epoch 119/1000
# 15536/15536 - 7s - loss: 0.6854 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6814 - BuySell_Prediction_accuracy: 0.5511 - val_loss: 0.6918 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6867 - val_BuySell_Prediction_accuracy: 0.5252
# Epoch 120/1000
# 15536/15536 - 7s - loss: 0.6849 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6809 - BuySell_Prediction_accuracy: 0.5511 - val_loss: 0.6896 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6851 - val_BuySell_Prediction_accuracy: 0.5321
# Epoch 121/1000
# 15536/15536 - 8s - loss: 0.6851 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6811 - BuySell_Prediction_accuracy: 0.5504 - val_loss: 0.6891 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6856 - val_BuySell_Prediction_accuracy: 0.5359
# Epoch 122/1000
# 15536/15536 - 7s - loss: 0.6838 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6799 - BuySell_Prediction_accuracy: 0.5561 - val_loss: 0.6883 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6840 - val_BuySell_Prediction_accuracy: 0.5307
# Epoch 123/1000
# 15536/15536 - 7s - loss: 0.6832 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6792 - BuySell_Prediction_accuracy: 0.5537 - val_loss: 0.6944 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6894 - val_BuySell_Prediction_accuracy: 0.5211
# Epoch 124/1000
# 15536/15536 - 7s - loss: 0.6828 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6788 - BuySell_Prediction_accuracy: 0.5534 - val_loss: 0.6905 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6862 - val_BuySell_Prediction_accuracy: 0.5256
# Epoch 125/1000
# 15536/15536 - 7s - loss: 0.6816 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6777 - BuySell_Prediction_accuracy: 0.5593 - val_loss: 0.6930 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6890 - val_BuySell_Prediction_accuracy: 0.5314
# Epoch 126/1000
# 15536/15536 - 7s - loss: 0.6816 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6775 - BuySell_Prediction_accuracy: 0.5586 - val_loss: 0.6911 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6862 - val_BuySell_Prediction_accuracy: 0.5318
# Epoch 127/1000
# 15536/15536 - 7s - loss: 0.6807 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6766 - BuySell_Prediction_accuracy: 0.5554 - val_loss: 0.6867 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6822 - val_BuySell_Prediction_accuracy: 0.5369
# Epoch 128/1000
# 15536/15536 - 7s - loss: 0.6804 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6766 - BuySell_Prediction_accuracy: 0.5548 - val_loss: 0.6880 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6843 - val_BuySell_Prediction_accuracy: 0.5369
# Epoch 129/1000
# 15536/15536 - 7s - loss: 0.6818 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6778 - BuySell_Prediction_accuracy: 0.5536 - val_loss: 0.6870 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6827 - val_BuySell_Prediction_accuracy: 0.5431
# Epoch 130/1000
# 15536/15536 - 7s - loss: 0.6805 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6764 - BuySell_Prediction_accuracy: 0.5575 - val_loss: 0.6872 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6835 - val_BuySell_Prediction_accuracy: 0.5273
# Epoch 131/1000
# 15536/15536 - 7s - loss: 0.6798 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6758 - BuySell_Prediction_accuracy: 0.5631 - val_loss: 0.6880 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6836 - val_BuySell_Prediction_accuracy: 0.5393
# Epoch 132/1000
# 15536/15536 - 7s - loss: 0.6776 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6737 - BuySell_Prediction_accuracy: 0.5641 - val_loss: 0.6862 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6821 - val_BuySell_Prediction_accuracy: 0.5472
# Epoch 133/1000
# 15536/15536 - 7s - loss: 0.6778 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6739 - BuySell_Prediction_accuracy: 0.5665 - val_loss: 0.6946 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6909 - val_BuySell_Prediction_accuracy: 0.5208
# Epoch 134/1000
# 15536/15536 - 7s - loss: 0.6755 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6715 - BuySell_Prediction_accuracy: 0.5710 - val_loss: 0.6899 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6857 - val_BuySell_Prediction_accuracy: 0.5396
# Epoch 135/1000
# 15536/15536 - 7s - loss: 0.6771 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6733 - BuySell_Prediction_accuracy: 0.5704 - val_loss: 0.6856 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6806 - val_BuySell_Prediction_accuracy: 0.5424
# Epoch 136/1000
# 15536/15536 - 7s - loss: 0.6766 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6727 - BuySell_Prediction_accuracy: 0.5667 - val_loss: 0.6798 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6765 - val_BuySell_Prediction_accuracy: 0.5510
# Epoch 137/1000
# 15536/15536 - 7s - loss: 0.6744 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6704 - BuySell_Prediction_accuracy: 0.5689 - val_loss: 0.6853 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6813 - val_BuySell_Prediction_accuracy: 0.5462
# Epoch 138/1000
# 15536/15536 - 7s - loss: 0.6735 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6694 - BuySell_Prediction_accuracy: 0.5736 - val_loss: 0.6833 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6796 - val_BuySell_Prediction_accuracy: 0.5475
# Epoch 139/1000
# 15536/15536 - 7s - loss: 0.6722 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6683 - BuySell_Prediction_accuracy: 0.5754 - val_loss: 0.6820 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6779 - val_BuySell_Prediction_accuracy: 0.5479
# Epoch 140/1000
# 15536/15536 - 7s - loss: 0.6710 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6670 - BuySell_Prediction_accuracy: 0.5812 - val_loss: 0.6857 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6816 - val_BuySell_Prediction_accuracy: 0.5496
# Epoch 141/1000
# 15536/15536 - 7s - loss: 0.6711 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6673 - BuySell_Prediction_accuracy: 0.5774 - val_loss: 0.6890 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6848 - val_BuySell_Prediction_accuracy: 0.5475
# Epoch 142/1000
# 15536/15536 - 7s - loss: 0.6692 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6653 - BuySell_Prediction_accuracy: 0.5808 - val_loss: 0.6794 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6755 - val_BuySell_Prediction_accuracy: 0.5558
# Epoch 143/1000
# 15536/15536 - 7s - loss: 0.6680 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6640 - BuySell_Prediction_accuracy: 0.5805 - val_loss: 0.6875 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6833 - val_BuySell_Prediction_accuracy: 0.5469
# Epoch 144/1000
# 15536/15536 - 7s - loss: 0.6672 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6634 - BuySell_Prediction_accuracy: 0.5789 - val_loss: 0.6759 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6724 - val_BuySell_Prediction_accuracy: 0.5568
# Epoch 145/1000
# 15536/15536 - 7s - loss: 0.6637 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6600 - BuySell_Prediction_accuracy: 0.5848 - val_loss: 0.6786 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6746 - val_BuySell_Prediction_accuracy: 0.5592
# Epoch 146/1000
# 15536/15536 - 7s - loss: 0.6633 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6594 - BuySell_Prediction_accuracy: 0.5907 - val_loss: 0.6865 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6828 - val_BuySell_Prediction_accuracy: 0.5506
# Epoch 147/1000
# 15536/15536 - 7s - loss: 0.6618 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6581 - BuySell_Prediction_accuracy: 0.5868 - val_loss: 0.6767 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6724 - val_BuySell_Prediction_accuracy: 0.5578
# Epoch 148/1000
# 15536/15536 - 7s - loss: 0.6614 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6576 - BuySell_Prediction_accuracy: 0.5897 - val_loss: 0.6736 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6696 - val_BuySell_Prediction_accuracy: 0.5675
# Epoch 149/1000
# 15536/15536 - 7s - loss: 0.6594 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6556 - BuySell_Prediction_accuracy: 0.5931 - val_loss: 0.6825 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6783 - val_BuySell_Prediction_accuracy: 0.5664
# Epoch 150/1000
# 15536/15536 - 7s - loss: 0.6568 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6531 - BuySell_Prediction_accuracy: 0.5998 - val_loss: 0.6762 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6728 - val_BuySell_Prediction_accuracy: 0.5760
# Epoch 151/1000
# 15536/15536 - 7s - loss: 0.6540 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6501 - BuySell_Prediction_accuracy: 0.5997 - val_loss: 0.6766 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6723 - val_BuySell_Prediction_accuracy: 0.5733
# Epoch 152/1000
# 15536/15536 - 7s - loss: 0.6511 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6473 - BuySell_Prediction_accuracy: 0.6050 - val_loss: 0.6772 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6728 - val_BuySell_Prediction_accuracy: 0.5712
# Epoch 153/1000
# 15536/15536 - 8s - loss: 0.6453 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6414 - BuySell_Prediction_accuracy: 0.6162 - val_loss: 0.6757 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6716 - val_BuySell_Prediction_accuracy: 0.5723
# Epoch 154/1000
# 15536/15536 - 8s - loss: 0.6481 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6441 - BuySell_Prediction_accuracy: 0.6105 - val_loss: 0.6712 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6668 - val_BuySell_Prediction_accuracy: 0.5767
# Epoch 155/1000
# 15536/15536 - 8s - loss: 0.6459 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6421 - BuySell_Prediction_accuracy: 0.6109 - val_loss: 0.6708 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6675 - val_BuySell_Prediction_accuracy: 0.5767
# Epoch 156/1000
# 15536/15536 - 7s - loss: 0.6418 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6381 - BuySell_Prediction_accuracy: 0.6159 - val_loss: 0.6702 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6653 - val_BuySell_Prediction_accuracy: 0.5829
# Epoch 157/1000
# 15536/15536 - 7s - loss: 0.6401 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6365 - BuySell_Prediction_accuracy: 0.6182 - val_loss: 0.6580 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6534 - val_BuySell_Prediction_accuracy: 0.5901
# Epoch 158/1000
# 15536/15536 - 7s - loss: 0.6340 - Gradient_Prediction_loss: 0.0037 - BuySell_Prediction_loss: 0.6302 - BuySell_Prediction_accuracy: 0.6268 - val_loss: 0.6536 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6499 - val_BuySell_Prediction_accuracy: 0.5911
# Epoch 159/1000
# 15536/15536 - 7s - loss: 0.6315 - Gradient_Prediction_loss: 0.0037 - BuySell_Prediction_loss: 0.6278 - BuySell_Prediction_accuracy: 0.6251 - val_loss: 0.6659 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6623 - val_BuySell_Prediction_accuracy: 0.5908
# Epoch 160/1000
# 15536/15536 - 7s - loss: 0.6323 - Gradient_Prediction_loss: 0.0037 - BuySell_Prediction_loss: 0.6287 - BuySell_Prediction_accuracy: 0.6254 - val_loss: 0.6721 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6672 - val_BuySell_Prediction_accuracy: 0.5918
# Epoch 161/1000
# 15536/15536 - 7s - loss: 0.6260 - Gradient_Prediction_loss: 0.0037 - BuySell_Prediction_loss: 0.6221 - BuySell_Prediction_accuracy: 0.6323 - val_loss: 0.6752 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6723 - val_BuySell_Prediction_accuracy: 0.5778
# Epoch 162/1000
# 15536/15536 - 7s - loss: 0.6262 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6223 - BuySell_Prediction_accuracy: 0.6327 - val_loss: 0.6654 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6619 - val_BuySell_Prediction_accuracy: 0.5911
# Epoch 163/1000
# 15536/15536 - 7s - loss: 0.6206 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6167 - BuySell_Prediction_accuracy: 0.6387 - val_loss: 0.6569 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6542 - val_BuySell_Prediction_accuracy: 0.6001
# Epoch 164/1000
# 15536/15536 - 7s - loss: 0.6192 - Gradient_Prediction_loss: 0.0037 - BuySell_Prediction_loss: 0.6157 - BuySell_Prediction_accuracy: 0.6408 - val_loss: 0.6634 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6600 - val_BuySell_Prediction_accuracy: 0.5932
# Epoch 165/1000
# ...
# Epoch 947/1000
# 15536/15536 - 11s - loss: 0.1083 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1055 - BuySell_Prediction_accuracy: 0.9591 - val_loss: 0.9511 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.9561 - val_BuySell_Prediction_accuracy: 0.7216
# Epoch 948/1000
# 15536/15536 - 11s - loss: 0.1088 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1059 - BuySell_Prediction_accuracy: 0.9608 - val_loss: 0.8960 - val_Gradient_Prediction_loss: 0.0034 - val_BuySell_Prediction_loss: 0.9031 - val_BuySell_Prediction_accuracy: 0.7364
# Epoch 949/1000
# 15536/15536 - 12s - loss: 0.1080 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1051 - BuySell_Prediction_accuracy: 0.9597 - val_loss: 0.8828 - val_Gradient_Prediction_loss: 0.0034 - val_BuySell_Prediction_loss: 0.8838 - val_BuySell_Prediction_accuracy: 0.7298
# Epoch 950/1000
# 15536/15536 - 11s - loss: 0.1064 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1037 - BuySell_Prediction_accuracy: 0.9616 - val_loss: 1.0554 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 1.0548 - val_BuySell_Prediction_accuracy: 0.7257
# Epoch 951/1000
# 15536/15536 - 11s - loss: 0.1223 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1196 - BuySell_Prediction_accuracy: 0.9543 - val_loss: 0.8901 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.8916 - val_BuySell_Prediction_accuracy: 0.7185
# Epoch 952/1000
# 15536/15536 - 11s - loss: 0.1128 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1099 - BuySell_Prediction_accuracy: 0.9602 - val_loss: 0.8967 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.8963 - val_BuySell_Prediction_accuracy: 0.7381
# Epoch 953/1000
# 15536/15536 - 10s - loss: 0.1076 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1050 - BuySell_Prediction_accuracy: 0.9616 - val_loss: 0.9733 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9715 - val_BuySell_Prediction_accuracy: 0.7230
# Epoch 954/1000
# 15536/15536 - 11s - loss: 0.1108 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1080 - BuySell_Prediction_accuracy: 0.9593 - val_loss: 0.8923 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.8921 - val_BuySell_Prediction_accuracy: 0.7340
# Epoch 955/1000
# 15536/15536 - 11s - loss: 0.1139 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1113 - BuySell_Prediction_accuracy: 0.9589 - val_loss: 0.8992 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.8937 - val_BuySell_Prediction_accuracy: 0.7333
# Epoch 956/1000
# 15536/15536 - 11s - loss: 0.1096 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1069 - BuySell_Prediction_accuracy: 0.9595 - val_loss: 0.9549 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9539 - val_BuySell_Prediction_accuracy: 0.7288
# Epoch 957/1000
# 15536/15536 - 11s - loss: 0.1084 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1060 - BuySell_Prediction_accuracy: 0.9603 - val_loss: 0.9945 - val_Gradient_Prediction_loss: 0.0037 - val_BuySell_Prediction_loss: 0.9911 - val_BuySell_Prediction_accuracy: 0.7134
# Epoch 958/1000
# 15536/15536 - 11s - loss: 0.1130 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1101 - BuySell_Prediction_accuracy: 0.9593 - val_loss: 0.9606 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.9594 - val_BuySell_Prediction_accuracy: 0.7336
# Epoch 959/1000
# 15536/15536 - 12s - loss: 0.1111 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1085 - BuySell_Prediction_accuracy: 0.9604 - val_loss: 1.0135 - val_Gradient_Prediction_loss: 0.0037 - val_BuySell_Prediction_loss: 1.0094 - val_BuySell_Prediction_accuracy: 0.7123
# Epoch 960/1000
# 15536/15536 - 11s - loss: 0.1157 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1129 - BuySell_Prediction_accuracy: 0.9586 - val_loss: 0.9435 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9432 - val_BuySell_Prediction_accuracy: 0.7250
# Epoch 961/1000
# 15536/15536 - 10s - loss: 0.1038 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1012 - BuySell_Prediction_accuracy: 0.9619 - val_loss: 0.9417 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.9507 - val_BuySell_Prediction_accuracy: 0.7398
# Epoch 962/1000
# 15536/15536 - 11s - loss: 0.1180 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1154 - BuySell_Prediction_accuracy: 0.9577 - val_loss: 0.8885 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.8921 - val_BuySell_Prediction_accuracy: 0.7274
# Epoch 963/1000
# 15536/15536 - 11s - loss: 0.1095 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1068 - BuySell_Prediction_accuracy: 0.9604 - val_loss: 0.9965 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9978 - val_BuySell_Prediction_accuracy: 0.7240
# Epoch 964/1000
# 15536/15536 - 11s - loss: 0.1051 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1023 - BuySell_Prediction_accuracy: 0.9629 - val_loss: 0.9258 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.9275 - val_BuySell_Prediction_accuracy: 0.7367
# Epoch 965/1000
# 15536/15536 - 11s - loss: 0.1088 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1059 - BuySell_Prediction_accuracy: 0.9601 - val_loss: 0.9393 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.9445 - val_BuySell_Prediction_accuracy: 0.7250
# Epoch 966/1000
# 15536/15536 - 11s - loss: 0.1095 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1066 - BuySell_Prediction_accuracy: 0.9595 - val_loss: 0.9484 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.9494 - val_BuySell_Prediction_accuracy: 0.7329
# Epoch 967/1000
# 15536/15536 - 11s - loss: 0.1095 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1069 - BuySell_Prediction_accuracy: 0.9598 - val_loss: 0.9980 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9993 - val_BuySell_Prediction_accuracy: 0.7175
# Epoch 968/1000
# 15536/15536 - 11s - loss: 0.1091 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1063 - BuySell_Prediction_accuracy: 0.9609 - val_loss: 0.8717 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.8777 - val_BuySell_Prediction_accuracy: 0.7515
# Epoch 969/1000
# 15536/15536 - 11s - loss: 0.1122 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1096 - BuySell_Prediction_accuracy: 0.9607 - val_loss: 0.9517 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9513 - val_BuySell_Prediction_accuracy: 0.7370
# Epoch 970/1000
# 15536/15536 - 11s - loss: 0.1037 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1013 - BuySell_Prediction_accuracy: 0.9614 - val_loss: 1.0148 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 1.0215 - val_BuySell_Prediction_accuracy: 0.7278
# Epoch 971/1000
# 15536/15536 - 11s - loss: 0.1148 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1121 - BuySell_Prediction_accuracy: 0.9588 - val_loss: 0.9711 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9715 - val_BuySell_Prediction_accuracy: 0.7151
# Epoch 972/1000
# 15536/15536 - 12s - loss: 0.1040 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1013 - BuySell_Prediction_accuracy: 0.9623 - val_loss: 0.9649 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9679 - val_BuySell_Prediction_accuracy: 0.7116
# Epoch 973/1000
# 15536/15536 - 11s - loss: 0.1087 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1058 - BuySell_Prediction_accuracy: 0.9605 - val_loss: 1.0056 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 1.0095 - val_BuySell_Prediction_accuracy: 0.7261
# Epoch 974/1000
# 15536/15536 - 11s - loss: 0.1091 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1065 - BuySell_Prediction_accuracy: 0.9604 - val_loss: 0.9880 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9876 - val_BuySell_Prediction_accuracy: 0.7257
# Epoch 975/1000
# 15536/15536 - 12s - loss: 0.1121 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1093 - BuySell_Prediction_accuracy: 0.9587 - val_loss: 0.9371 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.9359 - val_BuySell_Prediction_accuracy: 0.7343
# Epoch 976/1000
# 15536/15536 - 11s - loss: 0.1112 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1086 - BuySell_Prediction_accuracy: 0.9584 - val_loss: 0.9702 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.9708 - val_BuySell_Prediction_accuracy: 0.7171
# Epoch 977/1000
# 15536/15536 - 11s - loss: 0.1111 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1084 - BuySell_Prediction_accuracy: 0.9582 - val_loss: 0.8991 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.9026 - val_BuySell_Prediction_accuracy: 0.7405
# Epoch 978/1000
# 15536/15536 - 11s - loss: 0.1101 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1075 - BuySell_Prediction_accuracy: 0.9603 - val_loss: 0.9240 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.9239 - val_BuySell_Prediction_accuracy: 0.7436
# Epoch 979/1000
# 15536/15536 - 11s - loss: 0.1090 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1064 - BuySell_Prediction_accuracy: 0.9603 - val_loss: 0.9488 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9525 - val_BuySell_Prediction_accuracy: 0.7274
# Epoch 980/1000
# 15536/15536 - 11s - loss: 0.1086 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1056 - BuySell_Prediction_accuracy: 0.9600 - val_loss: 0.9655 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9667 - val_BuySell_Prediction_accuracy: 0.7209
# Epoch 981/1000
# 15536/15536 - 11s - loss: 0.1046 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1020 - BuySell_Prediction_accuracy: 0.9622 - val_loss: 1.0514 - val_Gradient_Prediction_loss: 0.0037 - val_BuySell_Prediction_loss: 1.0485 - val_BuySell_Prediction_accuracy: 0.7120
# Epoch 982/1000
# 15536/15536 - 11s - loss: 0.1019 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.0993 - BuySell_Prediction_accuracy: 0.9627 - val_loss: 0.9881 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9871 - val_BuySell_Prediction_accuracy: 0.7312
# Epoch 983/1000
# 15536/15536 - 11s - loss: 0.1023 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.0996 - BuySell_Prediction_accuracy: 0.9632 - val_loss: 1.0173 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 1.0215 - val_BuySell_Prediction_accuracy: 0.7185
# Epoch 984/1000
# 15536/15536 - 11s - loss: 0.1112 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1088 - BuySell_Prediction_accuracy: 0.9589 - val_loss: 0.8304 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.8456 - val_BuySell_Prediction_accuracy: 0.7532
# Epoch 985/1000
# 15536/15536 - 12s - loss: 0.1122 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1094 - BuySell_Prediction_accuracy: 0.9604 - val_loss: 0.8536 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.8586 - val_BuySell_Prediction_accuracy: 0.7333
# Epoch 986/1000
# 15536/15536 - 12s - loss: 0.1022 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.0996 - BuySell_Prediction_accuracy: 0.9636 - val_loss: 0.9468 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.9463 - val_BuySell_Prediction_accuracy: 0.7360
# Epoch 987/1000
# 15536/15536 - 11s - loss: 0.1133 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1108 - BuySell_Prediction_accuracy: 0.9572 - val_loss: 0.9011 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.9002 - val_BuySell_Prediction_accuracy: 0.7381
# Epoch 988/1000
# 15536/15536 - 11s - loss: 0.1127 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1100 - BuySell_Prediction_accuracy: 0.9591 - val_loss: 0.8933 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.8894 - val_BuySell_Prediction_accuracy: 0.7415
# Epoch 989/1000
# 15536/15536 - 12s - loss: 0.1060 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1030 - BuySell_Prediction_accuracy: 0.9618 - val_loss: 0.9388 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9434 - val_BuySell_Prediction_accuracy: 0.7305
# Epoch 990/1000
# 15536/15536 - 11s - loss: 0.1103 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1077 - BuySell_Prediction_accuracy: 0.9600 - val_loss: 0.9623 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.9724 - val_BuySell_Prediction_accuracy: 0.7312
# Epoch 991/1000
# 15536/15536 - 12s - loss: 0.1085 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1058 - BuySell_Prediction_accuracy: 0.9589 - val_loss: 0.9813 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9894 - val_BuySell_Prediction_accuracy: 0.7364
# Epoch 992/1000
# 15536/15536 - 11s - loss: 0.1081 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1056 - BuySell_Prediction_accuracy: 0.9618 - val_loss: 0.9310 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9377 - val_BuySell_Prediction_accuracy: 0.7353
# Epoch 993/1000
# 15536/15536 - 11s - loss: 0.1083 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1054 - BuySell_Prediction_accuracy: 0.9612 - val_loss: 0.9314 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9348 - val_BuySell_Prediction_accuracy: 0.7302
# Epoch 994/1000
# 15536/15536 - 11s - loss: 0.1098 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1073 - BuySell_Prediction_accuracy: 0.9601 - val_loss: 0.8923 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.8947 - val_BuySell_Prediction_accuracy: 0.7473
# Epoch 995/1000
# 15536/15536 - 11s - loss: 0.1107 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1079 - BuySell_Prediction_accuracy: 0.9590 - val_loss: 0.9689 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9706 - val_BuySell_Prediction_accuracy: 0.7226
# Epoch 996/1000
# 15536/15536 - 12s - loss: 0.1125 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1095 - BuySell_Prediction_accuracy: 0.9572 - val_loss: 0.9159 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9150 - val_BuySell_Prediction_accuracy: 0.7123
# Epoch 997/1000
# 15536/15536 - 11s - loss: 0.1080 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1051 - BuySell_Prediction_accuracy: 0.9607 - val_loss: 1.0055 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9970 - val_BuySell_Prediction_accuracy: 0.7254
# Epoch 998/1000
# 15536/15536 - 11s - loss: 0.1089 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1061 - BuySell_Prediction_accuracy: 0.9585 - val_loss: 1.0095 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 1.0095 - val_BuySell_Prediction_accuracy: 0.7195
# Epoch 999/1000
# 15536/15536 - 11s - loss: 0.1065 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1036 - BuySell_Prediction_accuracy: 0.9611 - val_loss: 0.9710 - val_Gradient_Prediction_loss: 0.0036 - val_BuySell_Prediction_loss: 0.9721 - val_BuySell_Prediction_accuracy: 0.7305
# Epoch 1000/1000
# 15536/15536 - 11s - loss: 0.1044 - Gradient_Prediction_loss: 0.0027 - BuySell_Prediction_loss: 0.1017 - BuySell_Prediction_accuracy: 0.9602 - val_loss: 0.9532 - val_Gradient_Prediction_loss: 0.0035 - val_BuySell_Prediction_loss: 0.9566 - val_BuySell_Prediction_accuracy: 0.7291
# Elapsed time is 7862.352046012878 seconds.

# %% [markdown]
# ## Visualization of training step

# %%
## Loss plots
lossfig, lossaxes = plt.subplots(nrows=1, ncols=3, figsize=(15,4))

lossfig.suptitle('Loss', fontsize=16)

lossaxes[0].plot(model_history.history['loss'], label='Training')
lossaxes[0].plot(model_history.history['val_loss'], label='Validation')
lossaxes[0].set_title('Overall Loss')

lossaxes[1].plot(model_history.history['Gradient_Prediction_loss'], label='Training')
lossaxes[1].plot(model_history.history['val_Gradient_Prediction_loss'], label='Validation')
lossaxes[1].set_title('Gradient prediction loss')

lossaxes[2].plot(model_history.history['BuySell_Prediction_loss'], label='Training')
lossaxes[2].plot(model_history.history['val_BuySell_Prediction_loss'], label='Validation')
lossaxes[2].set_title('BuySell Prediction loss')

## Accuracy plot
accfig, accaxes = plt.subplots(nrows=1, ncols=1, figsize=(15,4))

accfig.suptitle('Accuracy', fontsize=16)

accaxes.plot(model_history.history['BuySell_Prediction_accuracy'], label='Training')
accaxes.plot(model_history.history['val_BuySell_Prediction_accuracy'], label='Training');

# %% [markdown]
# The model achieve quite high accuracy on the validation training set however looking at the classification loss there seem to be some kind of overfitting going on. The best weights is saved, based on accuracy and for the rest of the notebook it is those weights that will be used.

# %% [markdown]
# ## Evaluating test data <a class="anchor" id="Test-eval">
#
# To visualize how well the model generalizes we look at the test data, which is data that the model never has seen before. We visualize both the prediction of the change in index and the classification accuracy.

# %%
lstm_model.load_weights('twoOutputCheckpoints/cp.ckpt')
lstm_model.evaluate(test_features, [test_label1, test_label2])
prediction = lstm_model.predict(test_features)

## Confusion matrix
conf_mat = confusion_matrix(test_label2, (prediction[1] > 0.5), normalize = 'true')
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(18,10))
sn.set(font_scale=1.4) # for label size
sn.heatmap(conf_mat, ax=ax, annot=True, annot_kws={"size": 16}, cmap='Blues', vmin=0, vmax=1) # font size
plt.xticks(ticks=np.arange(2), labels=['Sell', 'Buy'])
plt.yticks(ticks=np.arange(2), labels=['Sell', 'Buy'])
plt.xlabel('Predictions')
plt.ylabel('True')
plt.title('Confusion matrix')
plt.show()

## Roc curve
fpr, tpr, _ = roc_curve(test_label2, prediction[1])
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic buy sell prediction')
plt.legend(loc="lower right")
plt.show()
# Out:
# 972/972 [==============================] - 0s 343us/sample - loss: 0.7908 - Gradient_Prediction_loss: 0.0034 - BuySell_Prediction_loss: 0.7821 - BuySell_Prediction_accuracy: 0.7665

# %% [markdown]
# As seen by the confusion matrix the model performs quite good on the test data. Most interesting is actually the false positive and the false negative as this would be were the model looses money. You can see that when the index goes up only 23% of the times the model does not classify correctly and in 77% of the cases it is on the money. If you rely only on a strategy were you go long the false positive (the top right) is what you want to minimize. And if you rely on a stategy were it is possible to go both long and short you will have to take both false negatives and false positives into account. So hopefully when the model classifies correctly the return will out weigh the negative return the occurs when the classsifcation is off.

# %% [markdown]
# ## Backtesting <a class="anchor" id="Backtesting">
# To see how the model performs in "real" life data from a index that the model has never seen is pulled from yahoo finance. In this case OMX30 (Stockholm) to actually see if the model has a positive return. 3 different straegies is benchmarked against each other.
#
# * Passive - Buy and hold strategy.
# * Long only - The model is only allowed to go long in the asset.
# * Long and short - The model is allowed to go both long and short in the asset.
#
# Trading costs is not considered in this backtest which is a relevant factor especially when the trading frequency possibly could be daily. The passive strategy is considered as the benchmark for the model, i.e. what is the return of the indec if you passively invested in the index if doing this by ETF's or another product there would also be some recurring cost by just owning this product. These cost is not considered either.

# %%
## Backtrading
backtestIndex = yf.download('^OMX', start=startDate)
backtestIndex = pd.concat([backtestIndex, curr_vix_data], axis=1)
backtestIndex.fillna(method='ffill', inplace=True)
backtestIndex.drop(['Volume', 'Adj Close'], axis=1, inplace=True)
backtestIndex = addFeatures(backtestIndex)

backtestIndex.loc[:, 'Gradient'] = ((backtestIndex.loc[:, 'Close'] - backtestIndex.loc[:, 'Close'].shift())/backtestIndex.loc[:, 'Close'].shift() + 1).shift(-1)
backtestIndex.dropna(inplace=True)
buySell = backtestIndex.loc[:, 'Gradient'] > 1 

## Normalizing data
norm_backtestIndex = (backtestIndex - backtestIndex.min())/(backtestIndex.max() - backtestIndex.min())
norm_backtestIndex.loc[:, 'BuySell'] = buySell.astype(int)

backtestIndexFeatures, backtestIndexLabel1, backtestIndexLabel2 = nnFormat(norm_backtestIndex,sequence_length)

lstm_model.evaluate(backtestIndexFeatures, [backtestIndexLabel1, backtestIndexLabel2]);
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2756/2756 [==============================] - 1s 329us/sample - loss: 1.3566 - Gradient_Prediction_loss: 0.0085 - BuySell_Prediction_loss: 1.3551 - BuySell_Prediction_accuracy: 0.5943

# %% [markdown]
# The model achieves an accuracy of just around 60% which is far lower than the around the 75% accuracy in the test set.The decrease in accuracy can be explained by a number of things e.g the model has never seen the OMX 30 data or that the issues discussed with how the validation/test data were chosen actually had an impact. However in the stock market an accuracy of 60 % is not bad at all depending ofcause on how much you loose when the prediction is wrong.
#
# Lets take a look at how the model actually performs in terms of return.

# %%
backtradePredict = lstm_model.predict(backtestIndexFeatures)[1] > 0.5
closePrice = backtestIndex.iloc[backtestIndex.shape[0]-backtradePredict.shape[0]:, 25]
closePrice = pd.DataFrame(closePrice)
closePrice.loc[:, 'Prediction'] = backtradePredict
closePrice.loc[:, 'BuySell'] = (closePrice.loc[:,'Prediction']==False).astype(int) * -1 + closePrice.loc[:,'Prediction'].astype(int)
closePrice['LongStrat'] = ((closePrice['Gradient'] - 1) * closePrice['Prediction'] + 1).cumprod()
closePrice['LongShortStrat'] = ((closePrice['Gradient'] - 1) * closePrice['BuySell'] + 1).cumprod()

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(18,10))

ax = plt.plot(closePrice['Gradient'].cumprod(), label='Passive')
ax = plt.plot(closePrice['LongStrat'], label='Long')
ax = plt.plot(closePrice['LongShortStrat'], label='Long/Short')
plt.legend();

# %% [markdown]
# The graph above shows that the short and long strategy outperforms the passive strategy for the most part. For the first half a year the model there is not that big of a difference, but as time goes on both the long strategy and the long/short strat increases the gap to the passive strategy. The passive strategy would have resulted in a 70.2% increase compared to 306.9% and 453.8% of the only long and long/short respectively.

# %% [markdown]
# ## Conclusion <a class="anchor" id="Conclusion">
# So to sum up the well known sequence neural network that is LSTM have shown to be rather well to predict how the stock market moves. During training one could argue that the model seems to overfit based on validation set but nevertheless the accuracy on the test set was
