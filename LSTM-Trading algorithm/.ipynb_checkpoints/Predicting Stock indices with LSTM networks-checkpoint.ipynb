# %% [markdown]
# # Predicting stock indices using Long Short Term Memory networks
#
# ## Overview
#
# * [Technical indicators](#Technical-indicators)
# * [Data setup](#Downloading-cleaning)
# * [Basic EDA](#EDA)
# * [Model building](#Model-building)
# * [Hyperparameter optimization](#Hyperparameter-tuning)
# * [Training and vizualizing prediction error](#Training-vizu)
# * [Backtesting](#Backtesting)
# * [Conclusion](#Conclusion)
#
#
# ### Short introduction
#
# This notebook is a take on using LSTM recurrent neural networks for predicting stock markets in particular European indices. LSTM RNN have shown great success in trying to predict sequence data or timeseries and that is why the framework might be suitable for predicting stock markets. A typical classification problem can either be right or wrong and this is fine when modeling you are just modeling whether something belongs to a class. The issue with stock market predictions is that of course you would like to predict whether the market goes up or down, but also minimize the loss when your prediction is wrong. So the usual evaluation on accuracy is not enough which is were the backtesting becomes important. The model is tested on a index that were not available during training and the true performance is return of investment.
#
# The data that is used is some of the main indices from Europe but this framework can easily be expanded to include any other index or even be used on individual stock prices. Daily OHLC data from Yahoo Finance is easily accessible. Furthermore the data is enriched with currency exchange rates indices that might have some predictable power on the indices such as EURUSD, EURGBP etc. One of the hypothesis is that a volatility index would also have a predictive power however unfortunately the historical data from VDAX is not available from Yahoo Finance as a proxy we use the VIX, which could a measure of the overall volatility in the global economy and hopefully have some predictive power.

# %% [markdown]
# ## Packages imports

# %%
## Package imports
import os
import datetime

## The usual suspects
import pandas as pd
import numpy as np

## Visualization tools
# %matplotlib inline  
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.metrics import confusion_matrix, roc_curve, auc, roc_auc_score

## Packages for downloading financial data
import yfinance as yf

## Neural network tools
from tensorflow.keras.layers import Dense, LSTM, Dropout, BatchNormalization
from tensorflow.keras import Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint

## Bayesian optimization tools
from bayes_opt import BayesianOptimization
from functools import partial

## Set seed for reproduceability
np.random.seed(1)

# %%
## Function to time code.
def tic():
    import time
    global startTime_for_tictoc
    startTime_for_tictoc = time.time()

def toc():
    import time
    if 'startTime_for_tictoc' in globals():
        print("Elapsed time is " + str(time.time() - startTime_for_tictoc) + " seconds.")
    else:
        print("Toc: start time not set")
        
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("physical_devices-------------", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## Technical indicators as features <a class="anchor" id="Technical-indicators">
# Technical indicator is widely used by many practitioners (technical analysis) such as Simple Moving Averages (SMA), Bollinger Bands etc. to predict whether the stock is likely to move up or down. We enrich the data with some of the most common technical indicators SMA, Bollinger Bands, RSI, MACD and Fast Fourier Transforms. It can easily incorporate more indicators if needed

# %%
## Setup functions for adding features and format data
def macd(data, a, b):
    return data['Close'].ewm(span=a).mean() - data['Close'].ewm(span=b).mean()

def bollinger_bands(data, flag):
    sma = data['Close'].rolling(window=20).mean()
    smv = data['Close'].rolling(window=20).std()
    if flag == 'Upper':
        return sma + 2 * smv
    elif flag == 'Lower':
        return sma - 2 * smv
    else:
        raise ValueError('Wrong input.')
        
def rsi(data):
    df_ret = data['Close'].pct_change()
    g = df_ret * (df_ret > 0)
    l = df_ret * (df_ret < 0)
    avg_g = g.rolling(window=14).mean()
    avg_l = l.rolling(window=14).mean()
    rs = abs(avg_g.divide(avg_l))
    return 100 * rs / (1 + rs)

def fft_indicator(data, k):
    sp = np.fft.fft(data['Close'])
    return abs(np.fft.ifft(sp[:k], len(data)))

def addFeatures(data):
    sma_days = [10,50,100,200]

    for days in sma_days:
        data.loc[:, 'sma' + str(days)] = data['Close'].rolling(window=days).mean()
        data.loc[:, 'ema' + str(days)] = data['Close'].ewm(span=days).mean()

    data.loc[:, 'MACD'] = macd(data, 12, 26)
    data.loc[:, 'BB_Upper'] = bollinger_bands(data, 'Upper')
    data.loc[:, 'BB_Lower'] = bollinger_bands(data, 'Lower')
    data.loc[:, 'RSI'] = rsi(data)
    
    data.dropna(inplace=True)
    
    data.loc[:, 'fft3'] = fft_indicator(data,3)
    data.loc[:, 'fft6'] = fft_indicator(data,6)
    data.loc[:, 'fft9'] = fft_indicator(data,9)
    
    return data

def nnFormat(data, window=4):
    nrows = data.shape[0]
    ncols = data.shape[1]

    features = np.zeros(shape=(0, window, ncols - 2))
    label1 = np.zeros(shape=(0,1))
    label2 = np.zeros(shape=(0,1))
    
    for i in range(window,nrows-1):
        features = np.append(features, data.iloc[i-window:i,0:(ncols-2)].to_numpy().reshape(1, window, ncols - 2), axis=0)
        label1 = np.append(label1, data.iloc[i, ncols-2].reshape(1,1), axis=0)
        label2 = np.append(label2, data.iloc[i, ncols-1].reshape(1,1), axis=0)
    
    
    return features, label1, label2

# %% [markdown]
# ## Downloading and cleaning data <a class="anchor" id="Downloading-cleaning">

# %%
startDate = '2007-01-02'
endDate = '2020-04-10'

## Download currency data + VIX
curr_vix_list = ['EURUSD=X', 'EURGBP=X', 'EURSEK=X', 'EURJPY=X', 'EURCNY=X', '^VIX']
curr_vix_data = yf.download(curr_vix_list, start=startDate, end=endDate)
curr_vix_data = curr_vix_data['Close']
curr_vix_data = curr_vix_data.rename(columns={"EURUSD=X": "EURUSD", 
                                      "EURGBP=X": "EURGBP", 
                                      "EURSEK=X": "EURSEK", 
                                      "EURJPY=X": "EURJPY",
                                      "EURCNY=X": "EURCNY"})

indices = ['^STOXX50E', '^N100', '^BFX', '^GDAXI', '^FTSE', '^FCHI']

sequence_length = 20
features = np.zeros(shape=(0, sequence_length, 25))
label1 = np.zeros(shape=(0,1))
label2 = np.zeros(shape=(0,1))

for ind in indices:
    print(ind)
    data = yf.download(ind, start=startDate, end=endDate)
    data = pd.concat([data, curr_vix_data], axis=1)
    data.fillna(method='ffill', inplace=True)
    data.drop(['Volume', 'Adj Close'], axis=1, inplace=True)
    data = addFeatures(data)
    
    data.loc[:, 'Gradient'] = ((data.loc[:, 'Close'] - data.loc[:, 'Close'].shift())/data.loc[:, 'Close'].shift() + 1).shift(-1)
    data.dropna(inplace=True)
    buySell = data.loc[:, 'Gradient'] > 1 
    
    ## Normalizing data
    norm_data = (data - data.min())/(data.max() - data.min())
    norm_data.loc[:, 'BuySell'] = buySell.astype(int)
    
    tempFeatures, tempLabel1, tempLabel2 = nnFormat(norm_data,sequence_length)
    
    features = np.append(features, tempFeatures, axis=0)
    label1 = np.append(label1, tempLabel1, axis=0)
    label2 = np.append(label2, tempLabel2, axis=0)
# Out:
# [*********************100%***********************]  6 of 6 completed
# ^STOXX50E
# [*********************100%***********************]  1 of 1 completed
# ^N100
# [*********************100%***********************]  1 of 1 completed
# ^BFX
# [*********************100%***********************]  1 of 1 completed
# ^GDAXI
# [*********************100%***********************]  1 of 1 completed
# ^FTSE
# [*********************100%***********************]  1 of 1 completed
# ^FCHI
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Basic EDA <a class="anchor" id="EDA">
#
# Just to get a quick feel of how the data behaves we take a look at the German index DAX and the features that is added to the data.

# %%
data = yf.download('^GDAXI', start=startDate, progress=False)
data = pd.concat([data, curr_vix_data], axis=1)
data.fillna(method='ffill', inplace=True)
data.drop(['Volume', 'Adj Close'], axis=1, inplace=True)
data = addFeatures(data)

# %%
## Plot closing prices
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(18,10))
fig.suptitle('DAX', fontsize=20)
ax.set_ylabel('Close', fontsize=16)
ax.set_xlabel('Date', fontsize=16)
ax = data['Close'].plot(color=(31/255,119/255,180/255))
ax = data['sma50'].plot()
ax = data['sma200'].plot()
ax.legend();

# %% [markdown]
# Data since 2007-01-01 is included to have the latest financial crisis in the data and the reason for not taking all data available is that you could argue that algorithmic trading have gone up significantly over the last couple of years and have changed the way stocks and indices are being traded. This is what one would like to capture in a model and not how stocks were traded let's say 20 years ago.
#
# Two of the most common indicators (sma50 and sma200) have been depicted along side the historical and many more have been added as features. 6 different indicators is used in this model but with different parameters making it so that total of 15 extra features are added to the OHLC data.
#
# Next lets take a look at the correlation between the features in the model.

# %%
## Correlation plot
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(18,10))
sn.heatmap(data.corr(), cmap='Blues', ax=ax, vmin=-1, vmax=1)
ax.tick_params(axis='x', rotation=-45)
ax.invert_yaxis()

# %% [markdown]
# The correlation is set between -1 to 1 where 1 corresponds with perfect positive correlation i.e. if the close price goes up the feature also goes up in the similar fashion and -1 is then given by the opposite. As we would expect some of the simple features that is based on the close price have a close correlation with the close price. Remember the task is basically to predict the next close price.

# %% [markdown]
# ## Train-Val-Test-Split
#
# The split is done randomly from the dataset. So that every 20 length sequence with corresponding label is a independent observation. This however can be a problem when we look at the generalization error as the the model have been exposed to data points around the test set that is shared for training examples and test example because the each data point consist of a sequence of 20 days. You could instead base the validation set and training set on the dates such that newer data is the validation and test set respectively. The last section in this notebook a backtesting with an index that the model never has seen before is performed to see how well the model performs in terms of return.

# %%
## Splitting data into training, validation and test sets
index = np.random.permutation(features.shape[0])

training_idx, validation_idx, test_idx = index[:int(features.shape[0]*0.8)], index[int(features.shape[0]*0.8):int(features.shape[0]*0.95)], index[int(features.shape[0]*0.95):]
train_features, validation_features, test_features = features[training_idx,:], features[validation_idx,:], features[test_idx,:]
train_label1, validation_label1, test_label1 = label1[training_idx,:], label1[validation_idx,:], label1[test_idx,:]
train_label2, validation_label2, test_label2 = label2[training_idx,:], label2[validation_idx,:], label2[test_idx,:]

# %% [markdown]
# ## Model building <a class="anchor" id="Model-building">
#
# Different layouts for the model have been tried ending with a dual output LSTM model. The main idea of this model is to predict whether the index goes up or down the following period the intuitive way is to see this only as a classification problem but some problems may arise from this. If model is solely based on classification it is not penalized how far the model is from the actual change. This can result in that when the model makes a wrong prediction the loss can much higher than gain when the prediction is on point and the model is only evaluated on how if the price goes up or down. Which is why the model is built such that it also tries to predict the change in the index. Giving us a model that both minimizes the binary crossentropy on the classification problem and a mean squared error on prediction of the change in the index.
#
# One thing to be aware of when using LSTM is that the gradient can explode which is why clipping the gradient is used. Here we use keras implementation with the clipnorm. As a regularizer we use the simple dropout technique and treat learning rate, clipnorm dropout rate and layers in the LSTM and dense layer as hyperparameters to be optimized. For the dense layer just before the sigmoid layer the scaled exponential linear unit is used.

# %%
## Model building
def get_model(input_shape, 
              lstm_layer_1_nodes,
              lstm_layer_2_nodes,
              dense_layer_nodes,
              dropout_rate):
    
    input_layer = Input(shape=input_shape, name='Input_Layer')
    
    lstm_layer_1 = LSTM(lstm_layer_1_nodes, 
                        dropout = dropout_rate, 
                        return_sequences=True, 
                        name='First_LSTM_Layer')(input_layer)
    
    lstm_layer_2 = LSTM(lstm_layer_2_nodes, 
                        dropout = dropout_rate,
                        name='Second_LSTM_Layer')(lstm_layer_1)
    
   
    dense_layer_1 = Dense(dense_layer_nodes, 
                          activation='selu', 
                          name='First_Dense_Layer')(lstm_layer_2)
    
    output_layer_1 = Dense(1,
                          activation=None,
                          name='Gradient_Prediction')(lstm_layer_2)
    
    output_layer_2 = Dense(1,
                          activation='sigmoid',
                          name='BuySell_Prediction')(dense_layer_1)

    lstm_model = Model(input_layer, [output_layer_1, output_layer_2])
    
    
    return lstm_model

def fit_model(input_shape,
              lstm_nodes,
              dense_nodes,
              dropout_rate,
              lr,
              batch_size,
              clipnorm):

    lstm_model = get_model(input_shape, 
                           int(lstm_nodes),
                           int(lstm_nodes),
                           int(dense_nodes),
                           dropout_rate)
    
    opt = Adam(lr=lr, clipnorm=clipnorm)
    
    loss = {
    'Gradient_Prediction': 'mean_squared_error',
    'BuySell_Prediction': 'binary_crossentropy'
    }

    metrics = {
        'BuySell_Prediction': 'accuracy'
    }

    lstm_model.compile(optimizer=opt,
                      loss=loss,
                      metrics=metrics)
    
    mcp = ModelCheckpoint(checkpoint_path, 
                          monitor='val_loss', 
                          mode='min', 
                          save_best_only=True,
                          save_weights_only=True)
    
    lstm_model.fit(train_features, [train_label1, train_label2],
                   epochs=250,
                   batch_size=int(batch_size),
                   validation_data = [validation_features, {'Gradient_Prediction': validation_label1,
                                                            'BuySell_Prediction': validation_label2}],
                   callbacks=[mcp],
                   verbose=0)
    
    lstm_model.load_weights('baysianOpt/cp.ckpt')
    
    score = lstm_model.evaluate(validation_features, [validation_label1, validation_label2], verbose=0)

    return -score[0]

# %% [markdown]
# ## Hyperparameter tuning <a class="anchor" id="Hyperparameter-tuning">
#
# As stated above the parameters for tuning is the learning rate, clipnorm, the dropout rate for the lstm layers and then the nodes in the lstm layers and the dense layer. For this an implementation of baysian optimization is used. The baysian optimization makes the tuning of the hyperparameter into a new optimization problem meaning that hopefully the model does not have to go through to many iterations before a set of optimal or near optimal hyperparameters can be chosen to fully train the model. Because training a neural network can be computationally taxing the baysian optimization is done on 250 epochs with early stopping. Evaluating the performance of the model on the combined loss of the model.

# %%
## Baysian optimization

checkpoint_path = 'baysianOpt/cp.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)

fit_model_partial = partial(fit_model, (features.shape[1], features.shape[2]), batch_size=256)

tic()
pbounds = {'dropout_rate': (0.1, 0.35), 
           'lr': (1e-5, 1e-2),
           'clipnorm':(0.5,1.5),
           'lstm_nodes':(50,100),
           'dense_nodes':(50,100)}

optimizer = BayesianOptimization(
    f=fit_model_partial,
    pbounds=pbounds,
    verbose=2,
    random_state=1
)

optimizer.maximize(init_points=5, n_iter=20)

baysianOptimum = optimizer.max

toc()
# Out:
# |   iter    |  target   | clipnorm  | dense_... | dropou... |    lr     | lstm_n... |
# -------------------------------------------------------------------------------------
# |  1        | -0.5895   |  0.917    |  86.02    |  0.1      |  0.00303  |  57.34    |
# |  2        | -0.6606   |  0.5923   |  59.31    |  0.1864   |  0.003974 |  76.94    |
# |  3        | -0.6645   |  0.9192   |  84.26    |  0.1511   |  0.008782 |  51.37    |
# |  4        | -0.6882   |  1.17     |  70.87    |  0.2397   |  0.001412 |  59.91    |
# |  5        | -0.6395   |  1.301    |  98.41    |  0.1784   |  0.006926 |  93.82    |
# |  6        | -0.695    |  1.5      |  50.0     |  0.1      |  1e-05    |  100.0    |
# |  7        | -0.6964   |  0.5      |  100.0    |  0.35     |  1e-05    |  66.25    |
# |  8        | -0.6909   |  1.366    |  98.41    |  0.2969   |  0.004823 |  93.84    |
# |  9        | -0.6243   |  0.5      |  98.65    |  0.1      |  0.01     |  85.68    |
# |  10       | -0.6682   |  0.5      |  88.92    |  0.1      |  0.01     |  90.09    |
# |  11       | -0.6355   |  1.5      |  84.12    |  0.1      |  0.01     |  68.31    |
# |  12       | -0.662    |  1.5      |  96.99    |  0.1      |  0.009695 |  52.13    |
# |  13       | -0.618    |  1.5      |  75.42    |  0.1      |  0.01     |  78.84    |
# |  14       | -0.6544   |  1.5      |  70.37    |  0.1296   |  0.01     |  90.38    |
# |  15       | -0.6931   |  0.5      |  50.0     |  0.35     |  0.01     |  50.0     |
# |  16       | -0.6442   |  1.5      |  50.0     |  0.1      |  0.01     |  66.27    |
# |  17       | -0.6036   |  0.5      |  79.13    |  0.1      |  0.01     |  100.0    |
# |  18       | -0.684    |  1.254    |  50.12    |  0.222    |  0.004059 |  85.44    |
# |  19       | -0.6958   |  0.5      |  63.74    |  0.35     |  1e-05    |  100.0    |
# |  20       | -0.6699   |  0.5      |  89.65    |  0.1      |  0.000380 |  77.91    |
# |  21       | -0.6965   |  1.5      |  63.28    |  0.35     |  1e-05    |  50.0     |
# |  22       | -0.6938   |  0.5      |  60.86    |  0.35     |  0.01     |  65.24    |
# |  23       | -0.5868   |  0.5      |  91.24    |  0.1      |  0.01     |  100.0    |
# |  24       | -0.6273   |  0.5      |  59.25    |  0.1      |  0.01     |  89.75    |
# |  25       | -0.6049   |  0.5      |  100.0    |  0.1      |  0.01     |  100.0    |
# =====================================================================================
# Elapsed time is 4545.543745517731 seconds.

# %%
accuracy_list = [i['target'] for i in optimizer.res]
lstm_nodes_list = [int(i['params']['lstm_nodes']) for i in optimizer.res]
dense_nodes_list = [int(i['params']['dense_nodes']) for i in optimizer.res]
clipnorm_list = [i['params']['clipnorm'] for i in optimizer.res]
dropout_rate_list = [i['params']['dropout_rate'] for i in optimizer.res]
lr_list = [i['params']['lr'] for i in optimizer.res]


fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(15,8))
fig.suptitle('Baysian Optimization (n-iter=25)', fontsize=16)

ax[0][0].scatter(lstm_nodes_list, accuracy_list)
ax[0][0].set_title("lstm_nodes")

ax[0][1].scatter(dense_nodes_list, accuracy_list)
ax[0][1].set_title("dense_nodes")

ax[1][0].scatter(clipnorm_list, accuracy_list)
ax[1][0].set_title('Clipnorm')

ax[1][1].scatter(dropout_rate_list, accuracy_list)
ax[1][1].set_title('Dropout rate')

ax[2][0].scatter(lr_list, accuracy_list)
ax[2][0].set_title('Learning rate');


fig.delaxes(ax[2][1])

# %% [markdown]
# It is unclear whether the baysian optimization actually learned something, and we maybe should have used random search instead, which can be even more computationally taxing. For now we use the hyperparameters from the baysian optimization and try to do the full training.

# %%
input_shape = (features.shape[1], features.shape[2])
lstm_layer_1_nodes = 75
lstm_layer_2_nodes = 75
dense_layer_nodes = 50

useBayesian = True

if useBayesian:
    dropout_rate = baysianOptimum['params']['dropout_rate']
    batch_size = 256
    clipnorm = baysianOptimum['params']['clipnorm']
    lr = baysianOptimum['params']['lr']
    
    lstm_layer_1_nodes = int(baysianOptimum['params']['lstm_nodes'])
    lstm_layer_2_nodes = int(baysianOptimum['params']['lstm_nodes'])
    dense_layer_nodes = int(baysianOptimum['params']['dense_nodes'])
else:
    dropout_rate = 0.1
    batch_size = 256
    clipnorm = 1.12
    lr = 0.01

lstm_model = get_model(input_shape, 
              lstm_layer_1_nodes,
              lstm_layer_2_nodes,
              dense_layer_nodes,
              dropout_rate)

opt = Adam(lr=lr, clipnorm=clipnorm)

loss = {
    'Gradient_Prediction': 'mean_squared_error',
    'BuySell_Prediction': 'binary_crossentropy'
}

metrics = {
    'BuySell_Prediction': 'accuracy'
}
lstm_model.compile(optimizer=opt,
                  loss=loss,
                  metrics=metrics)

lstm_model.summary()
# Out:
# Model: "model_26"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input_Layer (InputLayer)        [(None, 20, 25)]     0
# __________________________________________________________________________________________________
# First_LSTM_Layer (LSTM)         (None, 20, 100)      50400       Input_Layer[0][0]
# __________________________________________________________________________________________________
# Second_LSTM_Layer (LSTM)        (None, 100)          80400       First_LSTM_Layer[0][0]
# __________________________________________________________________________________________________
# First_Dense_Layer (Dense)       (None, 87)           8787        Second_LSTM_Layer[0][0]
# __________________________________________________________________________________________________
# Gradient_Prediction (Dense)     (None, 1)            101         Second_LSTM_Layer[0][0]
# __________________________________________________________________________________________________
# BuySell_Prediction (Dense)      (None, 1)            88          First_Dense_Layer[0][0]
# ==================================================================================================
# Total params: 139,776
# Trainable params: 139,776
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Model training  <a class="anchor" id="Training-vizu">
#
# For model training we use the parameters from the baysian optimization and it seems that the model converges after aprox. 1000 epochs. During training we make checkpoints based on the accuracy making sure that we save the weights corresponding with the best performing model based on accuracy on the validation set (early stopping). This is done especially because the loss function is volatile but also to make it so that going forward we are sure to use the best model that were achieved through training.

# %%
## Setup Checkpoints for early stopping
checkpoint_path = 'twoOutputCheckpoints/cp.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)

mcp = ModelCheckpoint(checkpoint_path, 
                          monitor='val_BuySell_Prediction_accuracy', 
                          mode='max', 
                          save_best_only=True,
                          save_weights_only=True)

tic()
model_history = lstm_model.fit(train_features, 
                               {'Gradient_Prediction': train_label1,
                                'BuySell_Prediction': train_label2},
                               epochs=1000,
                               validation_data = [validation_features, {'Gradient_Prediction': validation_label1,
                                                                        'BuySell_Prediction': validation_label2}],
                               batch_size=batch_size,
                               callbacks=[mcp],
                               verbose=2
                              )
toc()
# Out:
# Train on 15508 samples, validate on 2907 samples
# Epoch 1/1000
# 15508/15508 - 3s - loss: 0.9246 - Gradient_Prediction_loss: 0.2168 - BuySell_Prediction_loss: 0.7063 - BuySell_Prediction_accuracy: 0.5003 - val_loss: 0.6974 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6930 - val_BuySell_Prediction_accuracy: 0.4909
# Epoch 2/1000
# 15508/15508 - 1s - loss: 0.6984 - Gradient_Prediction_loss: 0.0047 - BuySell_Prediction_loss: 0.6937 - BuySell_Prediction_accuracy: 0.5060 - val_loss: 0.6976 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6937 - val_BuySell_Prediction_accuracy: 0.5060
# Epoch 3/1000
# 15508/15508 - 1s - loss: 0.6985 - Gradient_Prediction_loss: 0.0045 - BuySell_Prediction_loss: 0.6940 - BuySell_Prediction_accuracy: 0.5039 - val_loss: 0.6974 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6936 - val_BuySell_Prediction_accuracy: 0.5119
# Epoch 4/1000
# 15508/15508 - 1s - loss: 0.6987 - Gradient_Prediction_loss: 0.0044 - BuySell_Prediction_loss: 0.6943 - BuySell_Prediction_accuracy: 0.5121 - val_loss: 0.6972 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6929 - val_BuySell_Prediction_accuracy: 0.5088
# Epoch 5/1000
# 15508/15508 - 1s - loss: 0.6975 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6931 - BuySell_Prediction_accuracy: 0.5055 - val_loss: 0.6971 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6930 - val_BuySell_Prediction_accuracy: 0.4995
# Epoch 6/1000
# 15508/15508 - 1s - loss: 0.6971 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6928 - BuySell_Prediction_accuracy: 0.5109 - val_loss: 0.6969 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6927 - val_BuySell_Prediction_accuracy: 0.5019
# Epoch 7/1000
# 15508/15508 - 1s - loss: 0.6975 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6932 - BuySell_Prediction_accuracy: 0.5059 - val_loss: 0.6970 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6930 - val_BuySell_Prediction_accuracy: 0.5019
# Epoch 8/1000
# 15508/15508 - 1s - loss: 0.6971 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6929 - BuySell_Prediction_accuracy: 0.5106 - val_loss: 0.6982 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6948 - val_BuySell_Prediction_accuracy: 0.5081
# Epoch 9/1000
# 15508/15508 - 1s - loss: 0.6975 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6932 - BuySell_Prediction_accuracy: 0.5046 - val_loss: 0.6979 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6933 - val_BuySell_Prediction_accuracy: 0.4967
# Epoch 10/1000
# 15508/15508 - 1s - loss: 0.6968 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6927 - BuySell_Prediction_accuracy: 0.5159 - val_loss: 0.6996 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6946 - val_BuySell_Prediction_accuracy: 0.5071
# Epoch 11/1000
# 15508/15508 - 1s - loss: 0.6969 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6926 - BuySell_Prediction_accuracy: 0.5144 - val_loss: 0.6969 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6929 - val_BuySell_Prediction_accuracy: 0.5022
# Epoch 12/1000
# 15508/15508 - 1s - loss: 0.6965 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6922 - BuySell_Prediction_accuracy: 0.5146 - val_loss: 0.6970 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6931 - val_BuySell_Prediction_accuracy: 0.5050
# Epoch 13/1000
# 15508/15508 - 1s - loss: 0.6966 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6924 - BuySell_Prediction_accuracy: 0.5182 - val_loss: 0.6968 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6927 - val_BuySell_Prediction_accuracy: 0.5081
# Epoch 14/1000
# 15508/15508 - 1s - loss: 0.6966 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6924 - BuySell_Prediction_accuracy: 0.5137 - val_loss: 0.6974 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6937 - val_BuySell_Prediction_accuracy: 0.5088
# Epoch 15/1000
# 15508/15508 - 1s - loss: 0.6969 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6927 - BuySell_Prediction_accuracy: 0.5110 - val_loss: 0.6975 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6931 - val_BuySell_Prediction_accuracy: 0.5108
# Epoch 16/1000
# 15508/15508 - 1s - loss: 0.6964 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6922 - BuySell_Prediction_accuracy: 0.5133 - val_loss: 0.6969 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6928 - val_BuySell_Prediction_accuracy: 0.5015
# Epoch 17/1000
# 15508/15508 - 1s - loss: 0.6967 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6925 - BuySell_Prediction_accuracy: 0.5099 - val_loss: 0.6968 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6930 - val_BuySell_Prediction_accuracy: 0.5009
# Epoch 18/1000
# 15508/15508 - 1s - loss: 0.6966 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6922 - BuySell_Prediction_accuracy: 0.5206 - val_loss: 0.6974 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6932 - val_BuySell_Prediction_accuracy: 0.5132
# Epoch 19/1000
# 15508/15508 - 1s - loss: 0.6963 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6921 - BuySell_Prediction_accuracy: 0.5164 - val_loss: 0.6968 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6926 - val_BuySell_Prediction_accuracy: 0.5126
# Epoch 20/1000
# 15508/15508 - 1s - loss: 0.6966 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6925 - BuySell_Prediction_accuracy: 0.5109 - val_loss: 0.6967 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6928 - val_BuySell_Prediction_accuracy: 0.5074
# Epoch 21/1000
# 15508/15508 - 1s - loss: 0.6966 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6923 - BuySell_Prediction_accuracy: 0.5132 - val_loss: 0.6973 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6938 - val_BuySell_Prediction_accuracy: 0.5046
# Epoch 22/1000
# 15508/15508 - 1s - loss: 0.6962 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6920 - BuySell_Prediction_accuracy: 0.5233 - val_loss: 0.6971 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6926 - val_BuySell_Prediction_accuracy: 0.5009
# Epoch 23/1000
# 15508/15508 - 1s - loss: 0.6964 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6922 - BuySell_Prediction_accuracy: 0.5175 - val_loss: 0.6967 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6926 - val_BuySell_Prediction_accuracy: 0.5091
# Epoch 24/1000
# 15508/15508 - 1s - loss: 0.6959 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6917 - BuySell_Prediction_accuracy: 0.5208 - val_loss: 0.6985 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6953 - val_BuySell_Prediction_accuracy: 0.5026
# Epoch 25/1000
# 15508/15508 - 1s - loss: 0.6969 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6927 - BuySell_Prediction_accuracy: 0.5110 - val_loss: 0.6979 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6948 - val_BuySell_Prediction_accuracy: 0.5074
# Epoch 26/1000
# 15508/15508 - 1s - loss: 0.6968 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6925 - BuySell_Prediction_accuracy: 0.5118 - val_loss: 0.6967 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6925 - val_BuySell_Prediction_accuracy: 0.5194
# Epoch 27/1000
# 15508/15508 - 1s - loss: 0.6965 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6922 - BuySell_Prediction_accuracy: 0.5204 - val_loss: 0.6962 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6921 - val_BuySell_Prediction_accuracy: 0.5243
# Epoch 28/1000
# 15508/15508 - 1s - loss: 0.6960 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6918 - BuySell_Prediction_accuracy: 0.5143 - val_loss: 0.6963 - val_Gradient_Prediction_loss: 0.0045 - val_BuySell_Prediction_loss: 0.6919 - val_BuySell_Prediction_accuracy: 0.5153
# Epoch 29/1000
# 15508/15508 - 1s - loss: 0.6958 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6915 - BuySell_Prediction_accuracy: 0.5201 - val_loss: 0.6969 - val_Gradient_Prediction_loss: 0.0047 - val_BuySell_Prediction_loss: 0.6927 - val_BuySell_Prediction_accuracy: 0.5157
# Epoch 30/1000
# 15508/15508 - 1s - loss: 0.6971 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6928 - BuySell_Prediction_accuracy: 0.5133 - val_loss: 0.6967 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6926 - val_BuySell_Prediction_accuracy: 0.5177
# Epoch 31/1000
# 15508/15508 - 1s - loss: 0.6956 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6914 - BuySell_Prediction_accuracy: 0.5241 - val_loss: 0.6974 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6934 - val_BuySell_Prediction_accuracy: 0.5232
# Epoch 32/1000
# 15508/15508 - 1s - loss: 0.6959 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6918 - BuySell_Prediction_accuracy: 0.5213 - val_loss: 0.6966 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6924 - val_BuySell_Prediction_accuracy: 0.5129
# Epoch 33/1000
# 15508/15508 - 1s - loss: 0.6969 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6927 - BuySell_Prediction_accuracy: 0.5180 - val_loss: 0.6963 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6923 - val_BuySell_Prediction_accuracy: 0.5157
# Epoch 34/1000
# 15508/15508 - 1s - loss: 0.6959 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6916 - BuySell_Prediction_accuracy: 0.5221 - val_loss: 0.6967 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6931 - val_BuySell_Prediction_accuracy: 0.5129
# Epoch 35/1000
# 15508/15508 - 1s - loss: 0.6955 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6912 - BuySell_Prediction_accuracy: 0.5230 - val_loss: 0.6965 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6923 - val_BuySell_Prediction_accuracy: 0.5136
# Epoch 36/1000
# 15508/15508 - 1s - loss: 0.6957 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6914 - BuySell_Prediction_accuracy: 0.5250 - val_loss: 0.6962 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6919 - val_BuySell_Prediction_accuracy: 0.5301
# Epoch 37/1000
# 15508/15508 - 1s - loss: 0.6960 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6918 - BuySell_Prediction_accuracy: 0.5236 - val_loss: 0.6960 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6918 - val_BuySell_Prediction_accuracy: 0.5208
# Epoch 38/1000
# 15508/15508 - 1s - loss: 0.6956 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6914 - BuySell_Prediction_accuracy: 0.5252 - val_loss: 0.6965 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6925 - val_BuySell_Prediction_accuracy: 0.5136
# Epoch 39/1000
# 15508/15508 - 1s - loss: 0.6955 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6913 - BuySell_Prediction_accuracy: 0.5274 - val_loss: 0.6971 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6931 - val_BuySell_Prediction_accuracy: 0.5115
# Epoch 40/1000
# 15508/15508 - 1s - loss: 0.6959 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6918 - BuySell_Prediction_accuracy: 0.5165 - val_loss: 0.6966 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6919 - val_BuySell_Prediction_accuracy: 0.5184
# Epoch 41/1000
# 15508/15508 - 1s - loss: 0.6958 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6917 - BuySell_Prediction_accuracy: 0.5235 - val_loss: 0.6960 - val_Gradient_Prediction_loss: 0.0043 - val_BuySell_Prediction_loss: 0.6918 - val_BuySell_Prediction_accuracy: 0.5163
# Epoch 42/1000
# 15508/15508 - 1s - loss: 0.6957 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6915 - BuySell_Prediction_accuracy: 0.5203 - val_loss: 0.6959 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6913 - val_BuySell_Prediction_accuracy: 0.5267
# Epoch 43/1000
# 15508/15508 - 1s - loss: 0.6951 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6908 - BuySell_Prediction_accuracy: 0.5235 - val_loss: 0.6979 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6929 - val_BuySell_Prediction_accuracy: 0.5077
# Epoch 44/1000
# 15508/15508 - 1s - loss: 0.6958 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6916 - BuySell_Prediction_accuracy: 0.5175 - val_loss: 0.6953 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6915 - val_BuySell_Prediction_accuracy: 0.5181
# Epoch 45/1000
# 15508/15508 - 1s - loss: 0.6956 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6914 - BuySell_Prediction_accuracy: 0.5273 - val_loss: 0.6960 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6920 - val_BuySell_Prediction_accuracy: 0.5246
# Epoch 46/1000
# 15508/15508 - 1s - loss: 0.6949 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6908 - BuySell_Prediction_accuracy: 0.5244 - val_loss: 0.6967 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6932 - val_BuySell_Prediction_accuracy: 0.5132
# Epoch 47/1000
# 15508/15508 - 1s - loss: 0.6942 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6901 - BuySell_Prediction_accuracy: 0.5297 - val_loss: 0.6976 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6926 - val_BuySell_Prediction_accuracy: 0.5232
# Epoch 48/1000
# 15508/15508 - 1s - loss: 0.6949 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6907 - BuySell_Prediction_accuracy: 0.5235 - val_loss: 0.6962 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6929 - val_BuySell_Prediction_accuracy: 0.5232
# Epoch 49/1000
# 15508/15508 - 1s - loss: 0.6946 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6904 - BuySell_Prediction_accuracy: 0.5285 - val_loss: 0.6954 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6911 - val_BuySell_Prediction_accuracy: 0.5339
# Epoch 50/1000
# 15508/15508 - 1s - loss: 0.6951 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6909 - BuySell_Prediction_accuracy: 0.5244 - val_loss: 0.6959 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6915 - val_BuySell_Prediction_accuracy: 0.5198
# Epoch 51/1000
# 15508/15508 - 1s - loss: 0.6951 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6909 - BuySell_Prediction_accuracy: 0.5271 - val_loss: 0.6975 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6928 - val_BuySell_Prediction_accuracy: 0.5046
# Epoch 52/1000
# 15508/15508 - 1s - loss: 0.6945 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6903 - BuySell_Prediction_accuracy: 0.5260 - val_loss: 0.6959 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6920 - val_BuySell_Prediction_accuracy: 0.5191
# Epoch 53/1000
# 15508/15508 - 1s - loss: 0.6947 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6905 - BuySell_Prediction_accuracy: 0.5313 - val_loss: 0.6985 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6939 - val_BuySell_Prediction_accuracy: 0.5218
# Epoch 54/1000
# 15508/15508 - 1s - loss: 0.6958 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6916 - BuySell_Prediction_accuracy: 0.5166 - val_loss: 0.6953 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6915 - val_BuySell_Prediction_accuracy: 0.5187
# Epoch 55/1000
# 15508/15508 - 1s - loss: 0.6947 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6905 - BuySell_Prediction_accuracy: 0.5279 - val_loss: 0.6975 - val_Gradient_Prediction_loss: 0.0049 - val_BuySell_Prediction_loss: 0.6931 - val_BuySell_Prediction_accuracy: 0.5198
# Epoch 56/1000
# 15508/15508 - 1s - loss: 0.6955 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6912 - BuySell_Prediction_accuracy: 0.5246 - val_loss: 0.6954 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6914 - val_BuySell_Prediction_accuracy: 0.5239
# Epoch 57/1000
# 15508/15508 - 1s - loss: 0.6947 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6905 - BuySell_Prediction_accuracy: 0.5283 - val_loss: 0.6957 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6915 - val_BuySell_Prediction_accuracy: 0.5187
# Epoch 58/1000
# 15508/15508 - 1s - loss: 0.6948 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6907 - BuySell_Prediction_accuracy: 0.5307 - val_loss: 0.6954 - val_Gradient_Prediction_loss: 0.0046 - val_BuySell_Prediction_loss: 0.6905 - val_BuySell_Prediction_accuracy: 0.5225
# Epoch 59/1000
# 15508/15508 - 1s - loss: 0.6951 - Gradient_Prediction_loss: 0.0043 - BuySell_Prediction_loss: 0.6908 - BuySell_Prediction_accuracy: 0.5225 - val_loss: 0.6972 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6941 - val_BuySell_Prediction_accuracy: 0.5150
# Epoch 60/1000
# 15508/15508 - 1s - loss: 0.6940 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6899 - BuySell_Prediction_accuracy: 0.5273 - val_loss: 0.6946 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6907 - val_BuySell_Prediction_accuracy: 0.5218
# Epoch 61/1000
# 15508/15508 - 1s - loss: 0.6945 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6904 - BuySell_Prediction_accuracy: 0.5259 - val_loss: 0.6986 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6934 - val_BuySell_Prediction_accuracy: 0.5084
# Epoch 62/1000
# 15508/15508 - 1s - loss: 0.6948 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6906 - BuySell_Prediction_accuracy: 0.5207 - val_loss: 0.6943 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6905 - val_BuySell_Prediction_accuracy: 0.5342
# Epoch 63/1000
# 15508/15508 - 1s - loss: 0.6953 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6912 - BuySell_Prediction_accuracy: 0.5215 - val_loss: 0.6952 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6908 - val_BuySell_Prediction_accuracy: 0.5132
# Epoch 64/1000
# 15508/15508 - 1s - loss: 0.6947 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6905 - BuySell_Prediction_accuracy: 0.5266 - val_loss: 0.6960 - val_Gradient_Prediction_loss: 0.0048 - val_BuySell_Prediction_loss: 0.6913 - val_BuySell_Prediction_accuracy: 0.5249
# Epoch 65/1000
# 15508/15508 - 1s - loss: 0.6946 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6903 - BuySell_Prediction_accuracy: 0.5224 - val_loss: 0.6951 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6917 - val_BuySell_Prediction_accuracy: 0.5215
# Epoch 66/1000
# 15508/15508 - 1s - loss: 0.6943 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6901 - BuySell_Prediction_accuracy: 0.5295 - val_loss: 0.6949 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6913 - val_BuySell_Prediction_accuracy: 0.5311
# Epoch 67/1000
# 15508/15508 - 1s - loss: 0.6940 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6899 - BuySell_Prediction_accuracy: 0.5268 - val_loss: 0.6942 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6901 - val_BuySell_Prediction_accuracy: 0.5267
# Epoch 68/1000
# 15508/15508 - 1s - loss: 0.6931 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6890 - BuySell_Prediction_accuracy: 0.5317 - val_loss: 0.6962 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6926 - val_BuySell_Prediction_accuracy: 0.5225
# Epoch 69/1000
# 15508/15508 - 1s - loss: 0.6936 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6894 - BuySell_Prediction_accuracy: 0.5251 - val_loss: 0.6943 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6905 - val_BuySell_Prediction_accuracy: 0.5298
# Epoch 70/1000
# 15508/15508 - 1s - loss: 0.6942 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6900 - BuySell_Prediction_accuracy: 0.5272 - val_loss: 0.6939 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6895 - val_BuySell_Prediction_accuracy: 0.5273
# Epoch 71/1000
# 15508/15508 - 1s - loss: 0.6928 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6887 - BuySell_Prediction_accuracy: 0.5310 - val_loss: 0.6956 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6924 - val_BuySell_Prediction_accuracy: 0.5194
# Epoch 72/1000
# 15508/15508 - 1s - loss: 0.6940 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6899 - BuySell_Prediction_accuracy: 0.5261 - val_loss: 0.6962 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6914 - val_BuySell_Prediction_accuracy: 0.5119
# Epoch 73/1000
# 15508/15508 - 1s - loss: 0.6936 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6894 - BuySell_Prediction_accuracy: 0.5311 - val_loss: 0.6934 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6893 - val_BuySell_Prediction_accuracy: 0.5335
# Epoch 74/1000
# 15508/15508 - 1s - loss: 0.6936 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6894 - BuySell_Prediction_accuracy: 0.5298 - val_loss: 0.6938 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6902 - val_BuySell_Prediction_accuracy: 0.5277
# Epoch 75/1000
# 15508/15508 - 1s - loss: 0.6936 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6895 - BuySell_Prediction_accuracy: 0.5291 - val_loss: 0.6945 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6900 - val_BuySell_Prediction_accuracy: 0.5215
# Epoch 76/1000
# 15508/15508 - 1s - loss: 0.6939 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6896 - BuySell_Prediction_accuracy: 0.5257 - val_loss: 0.6941 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6901 - val_BuySell_Prediction_accuracy: 0.5335
# Epoch 77/1000
# 15508/15508 - 1s - loss: 0.6934 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6893 - BuySell_Prediction_accuracy: 0.5281 - val_loss: 0.6940 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6906 - val_BuySell_Prediction_accuracy: 0.5270
# Epoch 78/1000
# 15508/15508 - 1s - loss: 0.6926 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6885 - BuySell_Prediction_accuracy: 0.5342 - val_loss: 0.6945 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6908 - val_BuySell_Prediction_accuracy: 0.5229
# Epoch 79/1000
# 15508/15508 - 1s - loss: 0.6932 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6892 - BuySell_Prediction_accuracy: 0.5259 - val_loss: 0.6942 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6896 - val_BuySell_Prediction_accuracy: 0.5273
# Epoch 80/1000
# 15508/15508 - 1s - loss: 0.6930 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6888 - BuySell_Prediction_accuracy: 0.5290 - val_loss: 0.6959 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6926 - val_BuySell_Prediction_accuracy: 0.5232
# Epoch 81/1000
# 15508/15508 - 1s - loss: 0.6931 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6890 - BuySell_Prediction_accuracy: 0.5277 - val_loss: 0.6942 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6899 - val_BuySell_Prediction_accuracy: 0.5198
# Epoch 82/1000
# 15508/15508 - 1s - loss: 0.6930 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6890 - BuySell_Prediction_accuracy: 0.5253 - val_loss: 0.6949 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6907 - val_BuySell_Prediction_accuracy: 0.5287
# Epoch 83/1000
# 15508/15508 - 1s - loss: 0.6931 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6889 - BuySell_Prediction_accuracy: 0.5301 - val_loss: 0.6944 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6907 - val_BuySell_Prediction_accuracy: 0.5298
# Epoch 84/1000
# 15508/15508 - 1s - loss: 0.6953 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6911 - BuySell_Prediction_accuracy: 0.5198 - val_loss: 0.6953 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6911 - val_BuySell_Prediction_accuracy: 0.5215
# Epoch 85/1000
# 15508/15508 - 1s - loss: 0.6939 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6898 - BuySell_Prediction_accuracy: 0.5262 - val_loss: 0.6967 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6916 - val_BuySell_Prediction_accuracy: 0.5129
# Epoch 86/1000
# 15508/15508 - 1s - loss: 0.6923 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6881 - BuySell_Prediction_accuracy: 0.5274 - val_loss: 0.6944 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6896 - val_BuySell_Prediction_accuracy: 0.5181
# Epoch 87/1000
# 15508/15508 - 1s - loss: 0.6930 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6889 - BuySell_Prediction_accuracy: 0.5294 - val_loss: 0.6930 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6890 - val_BuySell_Prediction_accuracy: 0.5318
# Epoch 88/1000
# 15508/15508 - 1s - loss: 0.6922 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6883 - BuySell_Prediction_accuracy: 0.5304 - val_loss: 0.6938 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6895 - val_BuySell_Prediction_accuracy: 0.5280
# Epoch 89/1000
# 15508/15508 - 1s - loss: 0.6917 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6876 - BuySell_Prediction_accuracy: 0.5328 - val_loss: 0.7003 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6974 - val_BuySell_Prediction_accuracy: 0.5115
# Epoch 90/1000
# 15508/15508 - 1s - loss: 0.6930 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6888 - BuySell_Prediction_accuracy: 0.5290 - val_loss: 0.6954 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6923 - val_BuySell_Prediction_accuracy: 0.5260
# Epoch 91/1000
# 15508/15508 - 1s - loss: 0.6930 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6890 - BuySell_Prediction_accuracy: 0.5302 - val_loss: 0.6978 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6925 - val_BuySell_Prediction_accuracy: 0.5136
# Epoch 92/1000
# 15508/15508 - 1s - loss: 0.6926 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6885 - BuySell_Prediction_accuracy: 0.5247 - val_loss: 0.6950 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6915 - val_BuySell_Prediction_accuracy: 0.5177
# Epoch 93/1000
# 15508/15508 - 1s - loss: 0.6927 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6885 - BuySell_Prediction_accuracy: 0.5257 - val_loss: 0.6955 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6910 - val_BuySell_Prediction_accuracy: 0.5160
# Epoch 94/1000
# 15508/15508 - 1s - loss: 0.6927 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6886 - BuySell_Prediction_accuracy: 0.5252 - val_loss: 0.6923 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6883 - val_BuySell_Prediction_accuracy: 0.5342
# Epoch 95/1000
# 15508/15508 - 1s - loss: 0.6915 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6874 - BuySell_Prediction_accuracy: 0.5380 - val_loss: 0.7001 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6968 - val_BuySell_Prediction_accuracy: 0.5187
# Epoch 96/1000
# 15508/15508 - 1s - loss: 0.6924 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6883 - BuySell_Prediction_accuracy: 0.5312 - val_loss: 0.6936 - val_Gradient_Prediction_loss: 0.0042 - val_BuySell_Prediction_loss: 0.6888 - val_BuySell_Prediction_accuracy: 0.5232
# Epoch 97/1000
# 15508/15508 - 1s - loss: 0.6919 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6877 - BuySell_Prediction_accuracy: 0.5287 - val_loss: 0.6926 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6885 - val_BuySell_Prediction_accuracy: 0.5363
# Epoch 98/1000
# 15508/15508 - 1s - loss: 0.6918 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6876 - BuySell_Prediction_accuracy: 0.5292 - val_loss: 0.6935 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6888 - val_BuySell_Prediction_accuracy: 0.5163
# Epoch 99/1000
# 15508/15508 - 1s - loss: 0.6919 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6878 - BuySell_Prediction_accuracy: 0.5314 - val_loss: 0.6919 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6873 - val_BuySell_Prediction_accuracy: 0.5291
# Epoch 100/1000
# 15508/15508 - 1s - loss: 0.6912 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6871 - BuySell_Prediction_accuracy: 0.5292 - val_loss: 0.6935 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6892 - val_BuySell_Prediction_accuracy: 0.5349
# Epoch 101/1000
# 15508/15508 - 1s - loss: 0.6918 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6876 - BuySell_Prediction_accuracy: 0.5339 - val_loss: 0.6917 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6872 - val_BuySell_Prediction_accuracy: 0.5359
# Epoch 102/1000
# 15508/15508 - 1s - loss: 0.6904 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6864 - BuySell_Prediction_accuracy: 0.5333 - val_loss: 0.6930 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6892 - val_BuySell_Prediction_accuracy: 0.5301
# Epoch 103/1000
# 15508/15508 - 1s - loss: 0.6901 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6859 - BuySell_Prediction_accuracy: 0.5346 - val_loss: 0.6915 - val_Gradient_Prediction_loss: 0.0044 - val_BuySell_Prediction_loss: 0.6867 - val_BuySell_Prediction_accuracy: 0.5315
# Epoch 104/1000
# 15508/15508 - 1s - loss: 0.6907 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6865 - BuySell_Prediction_accuracy: 0.5346 - val_loss: 0.6916 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6870 - val_BuySell_Prediction_accuracy: 0.5366
# Epoch 105/1000
# 15508/15508 - 1s - loss: 0.6900 - Gradient_Prediction_loss: 0.0042 - BuySell_Prediction_loss: 0.6858 - BuySell_Prediction_accuracy: 0.5326 - val_loss: 0.6939 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6900 - val_BuySell_Prediction_accuracy: 0.5249
# Epoch 106/1000
# 15508/15508 - 1s - loss: 0.6906 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6866 - BuySell_Prediction_accuracy: 0.5315 - val_loss: 0.6910 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6867 - val_BuySell_Prediction_accuracy: 0.5408
# Epoch 107/1000
# 15508/15508 - 1s - loss: 0.6895 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6856 - BuySell_Prediction_accuracy: 0.5360 - val_loss: 0.6899 - val_Gradient_Prediction_loss: 0.0041 - val_BuySell_Prediction_loss: 0.6862 - val_BuySell_Prediction_accuracy: 0.5373
# Epoch 108/1000
# 15508/15508 - 1s - loss: 0.6888 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6847 - BuySell_Prediction_accuracy: 0.5375 - val_loss: 0.6910 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6859 - val_BuySell_Prediction_accuracy: 0.5277
# Epoch 109/1000
# 15508/15508 - 1s - loss: 0.6887 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6847 - BuySell_Prediction_accuracy: 0.5349 - val_loss: 0.6940 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6905 - val_BuySell_Prediction_accuracy: 0.5291
# Epoch 110/1000
# 15508/15508 - 1s - loss: 0.6899 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6860 - BuySell_Prediction_accuracy: 0.5331 - val_loss: 0.6939 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6904 - val_BuySell_Prediction_accuracy: 0.5273
# Epoch 111/1000
# 15508/15508 - 1s - loss: 0.6892 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6851 - BuySell_Prediction_accuracy: 0.5456 - val_loss: 0.6883 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6845 - val_BuySell_Prediction_accuracy: 0.5421
# Epoch 112/1000
# 15508/15508 - 1s - loss: 0.6893 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6852 - BuySell_Prediction_accuracy: 0.5410 - val_loss: 0.6907 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6870 - val_BuySell_Prediction_accuracy: 0.5442
# Epoch 113/1000
# 15508/15508 - 1s - loss: 0.6894 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6854 - BuySell_Prediction_accuracy: 0.5299 - val_loss: 0.6914 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6872 - val_BuySell_Prediction_accuracy: 0.5377
# Epoch 114/1000
# 15508/15508 - 1s - loss: 0.6882 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6841 - BuySell_Prediction_accuracy: 0.5447 - val_loss: 0.6887 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6843 - val_BuySell_Prediction_accuracy: 0.5370
# Epoch 115/1000
# 15508/15508 - 1s - loss: 0.6875 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6836 - BuySell_Prediction_accuracy: 0.5435 - val_loss: 0.6874 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6831 - val_BuySell_Prediction_accuracy: 0.5404
# Epoch 116/1000
# 15508/15508 - 1s - loss: 0.6879 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6838 - BuySell_Prediction_accuracy: 0.5368 - val_loss: 0.6893 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6856 - val_BuySell_Prediction_accuracy: 0.5425
# Epoch 117/1000
# 15508/15508 - 1s - loss: 0.6885 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6842 - BuySell_Prediction_accuracy: 0.5392 - val_loss: 0.6909 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6861 - val_BuySell_Prediction_accuracy: 0.5332
# Epoch 118/1000
# 15508/15508 - 1s - loss: 0.6861 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6821 - BuySell_Prediction_accuracy: 0.5431 - val_loss: 0.6884 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6837 - val_BuySell_Prediction_accuracy: 0.5363
# Epoch 119/1000
# 15508/15508 - 1s - loss: 0.6878 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6839 - BuySell_Prediction_accuracy: 0.5381 - val_loss: 0.6918 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6873 - val_BuySell_Prediction_accuracy: 0.5339
# Epoch 120/1000
# 15508/15508 - 1s - loss: 0.6876 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6836 - BuySell_Prediction_accuracy: 0.5382 - val_loss: 0.6893 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6851 - val_BuySell_Prediction_accuracy: 0.5315
# Epoch 121/1000
# 15508/15508 - 1s - loss: 0.6878 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6837 - BuySell_Prediction_accuracy: 0.5389 - val_loss: 0.6887 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6846 - val_BuySell_Prediction_accuracy: 0.5432
# Epoch 122/1000
# 15508/15508 - 1s - loss: 0.6853 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6813 - BuySell_Prediction_accuracy: 0.5351 - val_loss: 0.6886 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6841 - val_BuySell_Prediction_accuracy: 0.5298
# Epoch 123/1000
# 15508/15508 - 1s - loss: 0.6854 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6816 - BuySell_Prediction_accuracy: 0.5419 - val_loss: 0.6846 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6808 - val_BuySell_Prediction_accuracy: 0.5580
# Epoch 124/1000
# 15508/15508 - 1s - loss: 0.6860 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6819 - BuySell_Prediction_accuracy: 0.5405 - val_loss: 0.6905 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6869 - val_BuySell_Prediction_accuracy: 0.5380
# Epoch 125/1000
# 15508/15508 - 1s - loss: 0.6842 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6801 - BuySell_Prediction_accuracy: 0.5485 - val_loss: 0.6881 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6857 - val_BuySell_Prediction_accuracy: 0.5277
# Epoch 126/1000
# 15508/15508 - 1s - loss: 0.6862 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6820 - BuySell_Prediction_accuracy: 0.5446 - val_loss: 0.6858 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6817 - val_BuySell_Prediction_accuracy: 0.5329
# Epoch 127/1000
# 15508/15508 - 1s - loss: 0.6831 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6791 - BuySell_Prediction_accuracy: 0.5479 - val_loss: 0.6881 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6846 - val_BuySell_Prediction_accuracy: 0.5435
# Epoch 128/1000
# 15508/15508 - 1s - loss: 0.6828 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6789 - BuySell_Prediction_accuracy: 0.5507 - val_loss: 0.6857 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6826 - val_BuySell_Prediction_accuracy: 0.5473
# Epoch 129/1000
# 15508/15508 - 1s - loss: 0.6847 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6806 - BuySell_Prediction_accuracy: 0.5458 - val_loss: 0.6893 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6856 - val_BuySell_Prediction_accuracy: 0.5387
# Epoch 130/1000
# 15508/15508 - 1s - loss: 0.6822 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6782 - BuySell_Prediction_accuracy: 0.5486 - val_loss: 0.6870 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6835 - val_BuySell_Prediction_accuracy: 0.5335
# Epoch 131/1000
# 15508/15508 - 1s - loss: 0.6838 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6798 - BuySell_Prediction_accuracy: 0.5484 - val_loss: 0.6848 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6805 - val_BuySell_Prediction_accuracy: 0.5387
# Epoch 132/1000
# 15508/15508 - 1s - loss: 0.6859 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6819 - BuySell_Prediction_accuracy: 0.5428 - val_loss: 0.6858 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6815 - val_BuySell_Prediction_accuracy: 0.5449
# Epoch 133/1000
# 15508/15508 - 1s - loss: 0.6834 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6794 - BuySell_Prediction_accuracy: 0.5444 - val_loss: 0.6799 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6758 - val_BuySell_Prediction_accuracy: 0.5507
# Epoch 134/1000
# 15508/15508 - 1s - loss: 0.6811 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6772 - BuySell_Prediction_accuracy: 0.5464 - val_loss: 0.6806 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6775 - val_BuySell_Prediction_accuracy: 0.5528
# Epoch 135/1000
# 15508/15508 - 1s - loss: 0.6794 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6755 - BuySell_Prediction_accuracy: 0.5513 - val_loss: 0.6831 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6793 - val_BuySell_Prediction_accuracy: 0.5397
# Epoch 136/1000
# 15508/15508 - 1s - loss: 0.6795 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6755 - BuySell_Prediction_accuracy: 0.5571 - val_loss: 0.6824 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6782 - val_BuySell_Prediction_accuracy: 0.5442
# Epoch 137/1000
# 15508/15508 - 1s - loss: 0.6857 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6818 - BuySell_Prediction_accuracy: 0.5474 - val_loss: 0.6979 - val_Gradient_Prediction_loss: 0.0040 - val_BuySell_Prediction_loss: 0.6932 - val_BuySell_Prediction_accuracy: 0.5232
# Epoch 138/1000
# 15508/15508 - 1s - loss: 0.6871 - Gradient_Prediction_loss: 0.0041 - BuySell_Prediction_loss: 0.6829 - BuySell_Prediction_accuracy: 0.5412 - val_loss: 0.6836 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6800 - val_BuySell_Prediction_accuracy: 0.5490
# Epoch 139/1000
# 15508/15508 - 1s - loss: 0.6802 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6761 - BuySell_Prediction_accuracy: 0.5445 - val_loss: 0.6864 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6824 - val_BuySell_Prediction_accuracy: 0.5377
# Epoch 140/1000
# 15508/15508 - 1s - loss: 0.6790 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6751 - BuySell_Prediction_accuracy: 0.5502 - val_loss: 0.6899 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6848 - val_BuySell_Prediction_accuracy: 0.5390
# Epoch 141/1000
# 15508/15508 - 1s - loss: 0.6753 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6716 - BuySell_Prediction_accuracy: 0.5587 - val_loss: 0.6807 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6762 - val_BuySell_Prediction_accuracy: 0.5432
# Epoch 142/1000
# 15508/15508 - 1s - loss: 0.6751 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6712 - BuySell_Prediction_accuracy: 0.5566 - val_loss: 0.6857 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6809 - val_BuySell_Prediction_accuracy: 0.5359
# Epoch 143/1000
# 15508/15508 - 1s - loss: 0.6739 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6701 - BuySell_Prediction_accuracy: 0.5630 - val_loss: 0.6817 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6784 - val_BuySell_Prediction_accuracy: 0.5514
# Epoch 144/1000
# 15508/15508 - 1s - loss: 0.6727 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6688 - BuySell_Prediction_accuracy: 0.5640 - val_loss: 0.6815 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6779 - val_BuySell_Prediction_accuracy: 0.5507
# Epoch 145/1000
# 15508/15508 - 1s - loss: 0.6738 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6698 - BuySell_Prediction_accuracy: 0.5647 - val_loss: 0.6825 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6798 - val_BuySell_Prediction_accuracy: 0.5542
# Epoch 146/1000
# 15508/15508 - 1s - loss: 0.6683 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6644 - BuySell_Prediction_accuracy: 0.5695 - val_loss: 0.6821 - val_Gradient_Prediction_loss: 0.0037 - val_BuySell_Prediction_loss: 0.6769 - val_BuySell_Prediction_accuracy: 0.5442
# Epoch 147/1000
# 15508/15508 - 1s - loss: 0.6718 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6677 - BuySell_Prediction_accuracy: 0.5600 - val_loss: 0.6794 - val_Gradient_Prediction_loss: 0.0037 - val_BuySell_Prediction_loss: 0.6751 - val_BuySell_Prediction_accuracy: 0.5366
# Epoch 148/1000
# 15508/15508 - 1s - loss: 0.6677 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6640 - BuySell_Prediction_accuracy: 0.5649 - val_loss: 0.6855 - val_Gradient_Prediction_loss: 0.0037 - val_BuySell_Prediction_loss: 0.6830 - val_BuySell_Prediction_accuracy: 0.5507
# Epoch 149/1000
# 15508/15508 - 1s - loss: 0.6765 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6722 - BuySell_Prediction_accuracy: 0.5480 - val_loss: 0.6798 - val_Gradient_Prediction_loss: 0.0039 - val_BuySell_Prediction_loss: 0.6758 - val_BuySell_Prediction_accuracy: 0.5545
# Epoch 150/1000
# 15508/15508 - 1s - loss: 0.6703 - Gradient_Prediction_loss: 0.0040 - BuySell_Prediction_loss: 0.6664 - BuySell_Prediction_accuracy: 0.5617 - val_loss: 0.6758 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6726 - val_BuySell_Prediction_accuracy: 0.5566
# Epoch 151/1000
# 15508/15508 - 1s - loss: 0.6667 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6630 - BuySell_Prediction_accuracy: 0.5667 - val_loss: 0.6769 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6734 - val_BuySell_Prediction_accuracy: 0.5614
# Epoch 152/1000
# 15508/15508 - 1s - loss: 0.6637 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6600 - BuySell_Prediction_accuracy: 0.5714 - val_loss: 0.6775 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6738 - val_BuySell_Prediction_accuracy: 0.5562
# Epoch 153/1000
# 15508/15508 - 1s - loss: 0.6653 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6613 - BuySell_Prediction_accuracy: 0.5666 - val_loss: 0.6730 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6692 - val_BuySell_Prediction_accuracy: 0.5587
# Epoch 154/1000
# 15508/15508 - 1s - loss: 0.6642 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6605 - BuySell_Prediction_accuracy: 0.5637 - val_loss: 0.6666 - val_Gradient_Prediction_loss: 0.0037 - val_BuySell_Prediction_loss: 0.6638 - val_BuySell_Prediction_accuracy: 0.5593
# Epoch 155/1000
# 15508/15508 - 1s - loss: 0.6628 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6590 - BuySell_Prediction_accuracy: 0.5666 - val_loss: 0.6723 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6684 - val_BuySell_Prediction_accuracy: 0.5645
# Epoch 156/1000
# 15508/15508 - 1s - loss: 0.6614 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6574 - BuySell_Prediction_accuracy: 0.5747 - val_loss: 0.6768 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6753 - val_BuySell_Prediction_accuracy: 0.5556
# Epoch 157/1000
# 15508/15508 - 1s - loss: 0.6605 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6565 - BuySell_Prediction_accuracy: 0.5694 - val_loss: 0.6664 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6635 - val_BuySell_Prediction_accuracy: 0.5597
# Epoch 158/1000
# 15508/15508 - 1s - loss: 0.6566 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6527 - BuySell_Prediction_accuracy: 0.5696 - val_loss: 0.6724 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6697 - val_BuySell_Prediction_accuracy: 0.5700
# Epoch 159/1000
# 15508/15508 - 1s - loss: 0.6563 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6526 - BuySell_Prediction_accuracy: 0.5725 - val_loss: 0.6768 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6755 - val_BuySell_Prediction_accuracy: 0.5531
# Epoch 160/1000
# 15508/15508 - 1s - loss: 0.6573 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6537 - BuySell_Prediction_accuracy: 0.5736 - val_loss: 0.6720 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6713 - val_BuySell_Prediction_accuracy: 0.5583
# Epoch 161/1000
# 15508/15508 - 1s - loss: 0.6542 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6505 - BuySell_Prediction_accuracy: 0.5780 - val_loss: 0.6688 - val_Gradient_Prediction_loss: 0.0037 - val_BuySell_Prediction_loss: 0.6654 - val_BuySell_Prediction_accuracy: 0.5648
# Epoch 162/1000
# 15508/15508 - 1s - loss: 0.6556 - Gradient_Prediction_loss: 0.0039 - BuySell_Prediction_loss: 0.6520 - BuySell_Prediction_accuracy: 0.5775 - val_loss: 0.6754 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6711 - val_BuySell_Prediction_accuracy: 0.5559
# Epoch 163/1000
# 15508/15508 - 1s - loss: 0.6587 - Gradient_Prediction_loss: 0.0038 - BuySell_Prediction_loss: 0.6547 - BuySell_Prediction_accuracy: 0.5723 - val_loss: 0.6685 - val_Gradient_Prediction_loss: 0.0038 - val_BuySell_Prediction_loss: 0.6650 - val_BuySell_Prediction_accuracy: 0.5714
# Epoch 164/1000
# 15508/15508 - 1s - loss: 0.6508 - Gradient_Prediction_loss: 0.0037 - BuySell_Prediction_loss: 0.6473 - BuySell_Prediction_accuracy: 0.5825 - val_loss: 0.6625 - val_Gradient_Prediction_loss: 0.0037 - val_BuySell_Prediction_loss: 0.6608 - val_BuySell_Prediction_accuracy: 0.5728
# Epoch 165/1000
# ...
# Epoch 947/1000
# 15508/15508 - 1s - loss: 0.1440 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1410 - BuySell_Prediction_accuracy: 0.9456 - val_loss: 0.7290 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7468 - val_BuySell_Prediction_accuracy: 0.7712
# Epoch 948/1000
# 15508/15508 - 1s - loss: 0.1529 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1505 - BuySell_Prediction_accuracy: 0.9383 - val_loss: 0.6915 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7078 - val_BuySell_Prediction_accuracy: 0.7754
# Epoch 949/1000
# 15508/15508 - 1s - loss: 0.1544 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1513 - BuySell_Prediction_accuracy: 0.9403 - val_loss: 0.7347 - val_Gradient_Prediction_loss: 0.0032 - val_BuySell_Prediction_loss: 0.7394 - val_BuySell_Prediction_accuracy: 0.7688
# Epoch 950/1000
# 15508/15508 - 1s - loss: 0.1466 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1439 - BuySell_Prediction_accuracy: 0.9431 - val_loss: 0.6897 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7086 - val_BuySell_Prediction_accuracy: 0.7898
# Epoch 951/1000
# 15508/15508 - 1s - loss: 0.1541 - Gradient_Prediction_loss: 0.0029 - BuySell_Prediction_loss: 0.1509 - BuySell_Prediction_accuracy: 0.9395 - val_loss: 0.7137 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7279 - val_BuySell_Prediction_accuracy: 0.7867
# Epoch 952/1000
# 15508/15508 - 1s - loss: 0.1548 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1518 - BuySell_Prediction_accuracy: 0.9404 - val_loss: 0.7047 - val_Gradient_Prediction_loss: 0.0032 - val_BuySell_Prediction_loss: 0.7180 - val_BuySell_Prediction_accuracy: 0.7730
# Epoch 953/1000
# 15508/15508 - 1s - loss: 0.1463 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1431 - BuySell_Prediction_accuracy: 0.9409 - val_loss: 0.6883 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.7120 - val_BuySell_Prediction_accuracy: 0.7833
# Epoch 954/1000
# 15508/15508 - 1s - loss: 0.1438 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1411 - BuySell_Prediction_accuracy: 0.9460 - val_loss: 0.7343 - val_Gradient_Prediction_loss: 0.0033 - val_BuySell_Prediction_loss: 0.7505 - val_BuySell_Prediction_accuracy: 0.7575
# Epoch 955/1000
# 15508/15508 - 1s - loss: 0.1389 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1359 - BuySell_Prediction_accuracy: 0.9472 - val_loss: 0.7293 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.7453 - val_BuySell_Prediction_accuracy: 0.7850
# Epoch 956/1000
# 15508/15508 - 1s - loss: 0.1463 - Gradient_Prediction_loss: 0.0029 - BuySell_Prediction_loss: 0.1432 - BuySell_Prediction_accuracy: 0.9447 - val_loss: 0.7075 - val_Gradient_Prediction_loss: 0.0033 - val_BuySell_Prediction_loss: 0.7254 - val_BuySell_Prediction_accuracy: 0.7730
# Epoch 957/1000
# 15508/15508 - 1s - loss: 0.1609 - Gradient_Prediction_loss: 0.0030 - BuySell_Prediction_loss: 0.1576 - BuySell_Prediction_accuracy: 0.9353 - val_loss: 0.7287 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7401 - val_BuySell_Prediction_accuracy: 0.7733
# Epoch 958/1000
# 15508/15508 - 1s - loss: 0.1472 - Gradient_Prediction_loss: 0.0029 - BuySell_Prediction_loss: 0.1444 - BuySell_Prediction_accuracy: 0.9433 - val_loss: 0.7939 - val_Gradient_Prediction_loss: 0.0032 - val_BuySell_Prediction_loss: 0.8021 - val_BuySell_Prediction_accuracy: 0.7337
# Epoch 959/1000
# 15508/15508 - 1s - loss: 0.1493 - Gradient_Prediction_loss: 0.0029 - BuySell_Prediction_loss: 0.1464 - BuySell_Prediction_accuracy: 0.9413 - val_loss: 0.7385 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7518 - val_BuySell_Prediction_accuracy: 0.7644
# Epoch 960/1000
# 15508/15508 - 1s - loss: 0.1459 - Gradient_Prediction_loss: 0.0029 - BuySell_Prediction_loss: 0.1433 - BuySell_Prediction_accuracy: 0.9431 - val_loss: 0.7172 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7306 - val_BuySell_Prediction_accuracy: 0.7647
# Epoch 961/1000
# 15508/15508 - 1s - loss: 0.1334 - Gradient_Prediction_loss: 0.0029 - BuySell_Prediction_loss: 0.1301 - BuySell_Prediction_accuracy: 0.9488 - val_loss: 0.7514 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.7672 - val_BuySell_Prediction_accuracy: 0.7798
# Epoch 962/1000
# 15508/15508 - 1s - loss: 0.1600 - Gradient_Prediction_loss: 0.0029 - BuySell_Prediction_loss: 0.1572 - BuySell_Prediction_accuracy: 0.9364 - val_loss: 0.7284 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.7339 - val_BuySell_Prediction_accuracy: 0.7613
# Epoch 963/1000
# 15508/15508 - 1s - loss: 0.1384 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1354 - BuySell_Prediction_accuracy: 0.9464 - val_loss: 0.7911 - val_Gradient_Prediction_loss: 0.0032 - val_BuySell_Prediction_loss: 0.7994 - val_BuySell_Prediction_accuracy: 0.7561
# Epoch 964/1000
# 15508/15508 - 1s - loss: 0.1526 - Gradient_Prediction_loss: 0.0029 - BuySell_Prediction_loss: 0.1498 - BuySell_Prediction_accuracy: 0.9424 - val_loss: 0.6576 - val_Gradient_Prediction_loss: 0.0029 - val_BuySell_Prediction_loss: 0.6671 - val_BuySell_Prediction_accuracy: 0.7850
# Epoch 965/1000
# 15508/15508 - 1s - loss: 0.1355 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1331 - BuySell_Prediction_accuracy: 0.9483 - val_loss: 0.7383 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.7489 - val_BuySell_Prediction_accuracy: 0.7809
# Epoch 966/1000
# 15508/15508 - 1s - loss: 0.1372 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1347 - BuySell_Prediction_accuracy: 0.9489 - val_loss: 0.7113 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.7219 - val_BuySell_Prediction_accuracy: 0.7764
# Epoch 967/1000
# 15508/15508 - 1s - loss: 0.1534 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1502 - BuySell_Prediction_accuracy: 0.9385 - val_loss: 0.7073 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7214 - val_BuySell_Prediction_accuracy: 0.7826
# Epoch 968/1000
# 15508/15508 - 1s - loss: 0.1458 - Gradient_Prediction_loss: 0.0029 - BuySell_Prediction_loss: 0.1429 - BuySell_Prediction_accuracy: 0.9460 - val_loss: 0.6830 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.6927 - val_BuySell_Prediction_accuracy: 0.7840
# Epoch 969/1000
# 15508/15508 - 1s - loss: 0.1422 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1393 - BuySell_Prediction_accuracy: 0.9462 - val_loss: 0.7374 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.7404 - val_BuySell_Prediction_accuracy: 0.7675
# Epoch 970/1000
# 15508/15508 - 1s - loss: 0.1457 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1423 - BuySell_Prediction_accuracy: 0.9418 - val_loss: 0.7119 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.7175 - val_BuySell_Prediction_accuracy: 0.7630
# Epoch 971/1000
# 15508/15508 - 1s - loss: 0.1364 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1335 - BuySell_Prediction_accuracy: 0.9467 - val_loss: 0.6883 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.7014 - val_BuySell_Prediction_accuracy: 0.7881
# Epoch 972/1000
# 15508/15508 - 1s - loss: 0.1366 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1340 - BuySell_Prediction_accuracy: 0.9458 - val_loss: 0.7468 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7635 - val_BuySell_Prediction_accuracy: 0.7747
# Epoch 973/1000
# 15508/15508 - 1s - loss: 0.1353 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1325 - BuySell_Prediction_accuracy: 0.9465 - val_loss: 0.7855 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.8070 - val_BuySell_Prediction_accuracy: 0.7620
# Epoch 974/1000
# 15508/15508 - 1s - loss: 0.1457 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1430 - BuySell_Prediction_accuracy: 0.9446 - val_loss: 0.6878 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.7054 - val_BuySell_Prediction_accuracy: 0.7767
# Epoch 975/1000
# 15508/15508 - 1s - loss: 0.1412 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1384 - BuySell_Prediction_accuracy: 0.9444 - val_loss: 0.7097 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7220 - val_BuySell_Prediction_accuracy: 0.7929
# Epoch 976/1000
# 15508/15508 - 1s - loss: 0.1385 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1355 - BuySell_Prediction_accuracy: 0.9449 - val_loss: 0.7511 - val_Gradient_Prediction_loss: 0.0032 - val_BuySell_Prediction_loss: 0.7579 - val_BuySell_Prediction_accuracy: 0.7740
# Epoch 977/1000
# 15508/15508 - 1s - loss: 0.1420 - Gradient_Prediction_loss: 0.0029 - BuySell_Prediction_loss: 0.1389 - BuySell_Prediction_accuracy: 0.9458 - val_loss: 0.7711 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7918 - val_BuySell_Prediction_accuracy: 0.7664
# Epoch 978/1000
# 15508/15508 - 1s - loss: 0.1444 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1418 - BuySell_Prediction_accuracy: 0.9444 - val_loss: 0.7789 - val_Gradient_Prediction_loss: 0.0032 - val_BuySell_Prediction_loss: 0.7967 - val_BuySell_Prediction_accuracy: 0.7630
# Epoch 979/1000
# 15508/15508 - 1s - loss: 0.1356 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1326 - BuySell_Prediction_accuracy: 0.9496 - val_loss: 0.7567 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7734 - val_BuySell_Prediction_accuracy: 0.7699
# Epoch 980/1000
# 15508/15508 - 1s - loss: 0.1368 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1340 - BuySell_Prediction_accuracy: 0.9474 - val_loss: 0.7980 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.8147 - val_BuySell_Prediction_accuracy: 0.7558
# Epoch 981/1000
# 15508/15508 - 1s - loss: 0.1393 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1373 - BuySell_Prediction_accuracy: 0.9458 - val_loss: 0.7319 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.7459 - val_BuySell_Prediction_accuracy: 0.7616
# Epoch 982/1000
# 15508/15508 - 1s - loss: 0.1311 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1281 - BuySell_Prediction_accuracy: 0.9517 - val_loss: 0.7099 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.7289 - val_BuySell_Prediction_accuracy: 0.7881
# Epoch 983/1000
# 15508/15508 - 1s - loss: 0.1356 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1325 - BuySell_Prediction_accuracy: 0.9512 - val_loss: 0.7128 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.7222 - val_BuySell_Prediction_accuracy: 0.7878
# Epoch 984/1000
# 15508/15508 - 1s - loss: 0.1343 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1315 - BuySell_Prediction_accuracy: 0.9487 - val_loss: 0.7232 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.7455 - val_BuySell_Prediction_accuracy: 0.7774
# Epoch 985/1000
# 15508/15508 - 1s - loss: 0.1314 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1285 - BuySell_Prediction_accuracy: 0.9509 - val_loss: 0.7906 - val_Gradient_Prediction_loss: 0.0032 - val_BuySell_Prediction_loss: 0.7948 - val_BuySell_Prediction_accuracy: 0.7589
# Epoch 986/1000
# 15508/15508 - 1s - loss: 0.1413 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1381 - BuySell_Prediction_accuracy: 0.9469 - val_loss: 0.7753 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7817 - val_BuySell_Prediction_accuracy: 0.7599
# Epoch 987/1000
# 15508/15508 - 1s - loss: 0.1381 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1351 - BuySell_Prediction_accuracy: 0.9471 - val_loss: 0.7177 - val_Gradient_Prediction_loss: 0.0032 - val_BuySell_Prediction_loss: 0.7300 - val_BuySell_Prediction_accuracy: 0.7723
# Epoch 988/1000
# 15508/15508 - 1s - loss: 0.1396 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1365 - BuySell_Prediction_accuracy: 0.9474 - val_loss: 0.7283 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7434 - val_BuySell_Prediction_accuracy: 0.7633
# Epoch 989/1000
# 15508/15508 - 1s - loss: 0.1548 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1521 - BuySell_Prediction_accuracy: 0.9387 - val_loss: 0.7096 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7143 - val_BuySell_Prediction_accuracy: 0.7853
# Epoch 990/1000
# 15508/15508 - 1s - loss: 0.1411 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1386 - BuySell_Prediction_accuracy: 0.9447 - val_loss: 0.7062 - val_Gradient_Prediction_loss: 0.0032 - val_BuySell_Prediction_loss: 0.7113 - val_BuySell_Prediction_accuracy: 0.7637
# Epoch 991/1000
# 15508/15508 - 1s - loss: 0.1375 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1345 - BuySell_Prediction_accuracy: 0.9458 - val_loss: 0.7381 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7566 - val_BuySell_Prediction_accuracy: 0.7754
# Epoch 992/1000
# 15508/15508 - 1s - loss: 0.1542 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1514 - BuySell_Prediction_accuracy: 0.9434 - val_loss: 0.7686 - val_Gradient_Prediction_loss: 0.0033 - val_BuySell_Prediction_loss: 0.7790 - val_BuySell_Prediction_accuracy: 0.7561
# Epoch 993/1000
# 15508/15508 - 1s - loss: 0.1450 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1433 - BuySell_Prediction_accuracy: 0.9438 - val_loss: 0.7415 - val_Gradient_Prediction_loss: 0.0032 - val_BuySell_Prediction_loss: 0.7501 - val_BuySell_Prediction_accuracy: 0.7637
# Epoch 994/1000
# 15508/15508 - 1s - loss: 0.1561 - Gradient_Prediction_loss: 0.0029 - BuySell_Prediction_loss: 0.1534 - BuySell_Prediction_accuracy: 0.9394 - val_loss: 0.7086 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7128 - val_BuySell_Prediction_accuracy: 0.7795
# Epoch 995/1000
# 15508/15508 - 1s - loss: 0.1322 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1294 - BuySell_Prediction_accuracy: 0.9493 - val_loss: 0.7285 - val_Gradient_Prediction_loss: 0.0032 - val_BuySell_Prediction_loss: 0.7392 - val_BuySell_Prediction_accuracy: 0.7692
# Epoch 996/1000
# 15508/15508 - 1s - loss: 0.1402 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1375 - BuySell_Prediction_accuracy: 0.9433 - val_loss: 0.7353 - val_Gradient_Prediction_loss: 0.0030 - val_BuySell_Prediction_loss: 0.7526 - val_BuySell_Prediction_accuracy: 0.7805
# Epoch 997/1000
# 15508/15508 - 1s - loss: 0.1342 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1317 - BuySell_Prediction_accuracy: 0.9493 - val_loss: 0.7175 - val_Gradient_Prediction_loss: 0.0032 - val_BuySell_Prediction_loss: 0.7279 - val_BuySell_Prediction_accuracy: 0.7902
# Epoch 998/1000
# 15508/15508 - 1s - loss: 0.1422 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1391 - BuySell_Prediction_accuracy: 0.9431 - val_loss: 0.7600 - val_Gradient_Prediction_loss: 0.0032 - val_BuySell_Prediction_loss: 0.7663 - val_BuySell_Prediction_accuracy: 0.7661
# Epoch 999/1000
# 15508/15508 - 1s - loss: 0.1394 - Gradient_Prediction_loss: 0.0029 - BuySell_Prediction_loss: 0.1360 - BuySell_Prediction_accuracy: 0.9476 - val_loss: 0.7192 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7342 - val_BuySell_Prediction_accuracy: 0.7891
# Epoch 1000/1000
# 15508/15508 - 1s - loss: 0.1387 - Gradient_Prediction_loss: 0.0028 - BuySell_Prediction_loss: 0.1362 - BuySell_Prediction_accuracy: 0.9460 - val_loss: 0.6944 - val_Gradient_Prediction_loss: 0.0031 - val_BuySell_Prediction_loss: 0.7076 - val_BuySell_Prediction_accuracy: 0.7864
# Elapsed time is 671.045937538147 seconds.

# %% [markdown]
# ## Visualization of training step

# %%
## Loss plots
lossfig, lossaxes = plt.subplots(nrows=1, ncols=3, figsize=(15,4))

lossfig.suptitle('Loss', fontsize=16)

lossaxes[0].plot(model_history.history['loss'], label='Training')
lossaxes[0].plot(model_history.history['val_loss'], label='Validation')
lossaxes[0].set_title('Overall Loss')

lossaxes[1].plot(model_history.history['Gradient_Prediction_loss'], label='Training')
lossaxes[1].plot(model_history.history['val_Gradient_Prediction_loss'], label='Validation')
lossaxes[1].set_title('Gradient prediction loss')

lossaxes[2].plot(model_history.history['BuySell_Prediction_loss'], label='Training')
lossaxes[2].plot(model_history.history['val_BuySell_Prediction_loss'], label='Validation')
lossaxes[2].set_title('BuySell Prediction loss')

## Accuracy plot
accfig, accaxes = plt.subplots(nrows=1, ncols=1, figsize=(15,4))

accfig.suptitle('Accuracy', fontsize=16)

accaxes.plot(model_history.history['BuySell_Prediction_accuracy'], label='Training')
accaxes.plot(model_history.history['val_BuySell_Prediction_accuracy'], label='Training');

# %% [markdown]
# The model achieve quite high accuracy on the validation training set however looking at the classification loss there seem to be some kind of overfitting going on. One could argue that the error term on the change of the price is not weighing enough on the full loss function and it could be interesting to see the performance if this where changed. The best weights is saved, based on accuracy and for the rest of the notebook it is those weights that will be used.

# %% [markdown]
# ## Evaluating test data <a class="anchor" id="Test-eval">
#
# To visualize how well the model generalizes we look at the test data.

# %%
lstm_model.load_weights('twoOutputCheckpoints/cp.ckpt')
lstm_model.evaluate(test_features, [test_label1, test_label2], verbose=2, batch_size=batch_size)
prediction = lstm_model.predict(test_features)

## Confusion matrix
conf_mat = confusion_matrix(test_label2, (prediction[1] > 0.5), normalize = 'true')
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(18,10))
sn.set(font_scale=1.4) # for label size
sn.heatmap(conf_mat, ax=ax, annot=True, annot_kws={"size": 16}, cmap='Blues', vmin=0, vmax=1) # font size
plt.xticks(ticks=np.arange(2), labels=['Sell', 'Buy'])
plt.yticks(ticks=np.arange(2), labels=['Sell', 'Buy'])
plt.xlabel('Predictions')
plt.ylabel('True')
plt.title('Confusion matrix')
plt.show()
# Out:
# 970/1 - 0s - loss: 0.5612 - Gradient_Prediction_loss: 0.0035 - BuySell_Prediction_loss: 0.5699 - BuySell_Prediction_accuracy: 0.7557

# %% [markdown]
# As seen by the confusion matrix the model performs quite good on the test data. Most interesting is actually the false positive and the false negative as this would be were the model looses money. You can see that when the index goes up only 23% of the times the model does not classify correctly and in 77% of the cases it is on the money. If you rely only on a strategy were you go long the false positive (the top right) is what you want to minimize. And if you rely on a strategy were it is possible to go both long and short you will have to take both false negatives and false positives into account. So hopefully when the model classifies correctly the return will out weigh the negative return the occurs when the classification is off. To investigate this further a backtesting of a index the model have not seen were performed.

# %% [markdown]
# ## Backtesting <a class="anchor" id="Backtesting">
# To see how the model performs in "real" life data from a index that the model has never seen is pulled from yahoo finance. In this case OMX30 (Stockholm) to actually see if the model has a positive return. 3 different strategies is benchmarked against each other.
#
# * Passive - Buy and hold strategy.
# * Long only - The model is only allowed to go long in the asset.
# * Long and short - The model is allowed to go both long and short in the asset.
#
# Trading costs is not considered in this backtest which is a relevant factor especially when the trading frequency possibly could be daily. The passive strategy is considered as the benchmark for the model, i.e. what is the return of the indec if you passively invested in the index if doing this by ETF's or another product there would also be some recurring cost by just owning this product. These cost is not considered either.

# %%
## Backtrading
backtestIndex = yf.download('^OMX', start=startDate)
backtestIndex = pd.concat([backtestIndex, curr_vix_data], axis=1)
backtestIndex.fillna(method='ffill', inplace=True)
backtestIndex.drop(['Volume', 'Adj Close'], axis=1, inplace=True)
backtestIndex = addFeatures(backtestIndex)

backtestIndex.loc[:, 'Gradient'] = ((backtestIndex.loc[:, 'Close'] - backtestIndex.loc[:, 'Close'].shift())/backtestIndex.loc[:, 'Close'].shift() + 1).shift(-1)
backtestIndex.dropna(inplace=True)
buySell = backtestIndex.loc[:, 'Gradient'] > 1 

## Normalizing data
norm_backtestIndex = (backtestIndex - backtestIndex.min())/(backtestIndex.max() - backtestIndex.min())
norm_backtestIndex.loc[:, 'BuySell'] = buySell.astype(int)

backtestIndexFeatures, backtestIndexLabel1, backtestIndexLabel2 = nnFormat(norm_backtestIndex,sequence_length)

lstm_model.evaluate(backtestIndexFeatures, [backtestIndexLabel1, backtestIndexLabel2], batch_size=batch_size, verbose=2);
# Out:
# [*********************100%***********************]  1 of 1 completed
# 2762/1 - 0s - loss: 0.7589 - Gradient_Prediction_loss: 0.0085 - BuySell_Prediction_loss: 0.8608 - BuySell_Prediction_accuracy: 0.6184

# %% [markdown]
# The model achieves an accuracy of just around 60% which is far lower than the around the 75% accuracy in the test set. The decrease in accuracy can be explained by a number of things e.g the model has never seen any data from the OMX 30 or that the issues discussed with how the validation/test data were chosen actually had an impact. However in the stock market an accuracy of 61 % is not bad at all depending of course on how much you loose when the prediction is wrong.
#
# Lets take a look at how the model actually performs in terms of return.

# %%
backtradePredict = lstm_model.predict(backtestIndexFeatures)[1] > 0.5
closePrice = backtestIndex.iloc[backtestIndex.shape[0]-backtradePredict.shape[0]:, 25]
closePrice = pd.DataFrame(closePrice)
closePrice.loc[:, 'Prediction'] = backtradePredict
closePrice.loc[:, 'BuySell'] = (closePrice.loc[:,'Prediction']==False).astype(int) * -1 + closePrice.loc[:,'Prediction'].astype(int)
closePrice['LongStrat'] = ((closePrice['Gradient'] - 1) * closePrice['Prediction'] + 1).cumprod()
closePrice['LongShortStrat'] = ((closePrice['Gradient'] - 1) * closePrice['BuySell'] + 1).cumprod()

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(18,10))

ax = plt.plot(closePrice['Gradient'].cumprod(), label='Passive')
ax = plt.plot(closePrice['LongStrat'], label='Long')
ax = plt.plot(closePrice['LongShortStrat'], label='Long/Short')
plt.legend();

# %% [markdown]
# The graph above shows that the short and long strategy outperforms the passive strategy for the most part. For the first half a year the model there is not that big of a difference, but as time goes on both the long strategy and the long/short strategy increases the gap to the passive strategy and clearly outperforms the simple passive strategy.

# %% [markdown]
# ## Conclusion <a class="anchor" id="Conclusion">
# So to sum up the well known sequence neural network that is LSTM have shown to be rather well to predict how the stock market moves. During training one could argue that the model seems to overfit based on validation set but nevertheless the accuracy on the test set still in the range of the validation set. And the backtesting of the model with an index that were not used in the training section could argue that the model does indeed learn something that can be used for earning money in the stock market.
#
# It would be possible to set up this as automated trading algorithm if your broker has somekind of API connection and in that case it would perhaps be interesting to look at this model with high frequency data, such as 1m ticks some similar, to see if it will also perform as well in intra day trading.
#
# Next steps in improving this model would be to look into the overfitting during training. This could be achieved by increasing the epochs during hyperparameter search because as it is now the overfitting happens in range where the hyperparameter search never reaches.
